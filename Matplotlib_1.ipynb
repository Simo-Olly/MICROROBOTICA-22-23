# %%
import matplotlib.pyplot as plt
import numpy as np
import os, shutil

# %%
os.chdir('C:\\Users\\Marco\\Desktop\\5° superiore\\MICROROBOTICA\\Es_Python')

# %%
x = np.linspace(-1, 1, 101)
f1 = 1/x
# Out:
# C:\Users\Marco\AppData\Local\Temp\ipykernel_9144\1058727934.py:2: RuntimeWarning: divide by zero encountered in true_divide
#   f1 = 1/x

# %%
fig, ax = plt.subplots(figsize = (6,6))
ax.plot(x, f1)
ax.grid("both")
plt.show()

# %% [markdown]
# ### ES

# %%
valori = np.random.uniform(0,1,5)
valori
# Out:
# array([0.78136452, 0.43347535, 0.43329881, 0.14465003, 0.82350381])

# %%
fig, ax = plt.subplots()
ax.plot(valori, marker = "v")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig, ax = plt.subplots()
ax.plot(valori, marker = "*")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig, ax = plt.subplots()
ax.plot(valori, marker = "*", markersize = 20)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig, ax = plt.subplots()
ax.plot(valori, marker = "*", markersize = 20, linestyle = "")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### ES sfondo stellato

# %%
n_star = 15
x = np.random.uniform(0.,1.,n_star)
y = np.random.uniform(0.,1.,n_star)

# %%
fig, ax = plt.subplots(figsize = (5,5))
ax.set_facecolor("black")
ax.plot(x,y, marker = "*", markersize = 20, linestyle = "", color = "yellow")
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Es sfonto stellato 2.0

# %%
n = np.random.randint(600,800)

blu_scuro = (0,0,24/255)
colori_stelle = (np.random.uniform(220,240)/255,np.random.uniform(240,255)/255,np.random.uniform(155,255)/255)

x = np.random.uniform(0.,1.,n)
y = np.random.uniform(0.,1.,n)
colori = np.random.uniform(0.,1.,(n,3))
dimensione = np.random.uniform(1.,15.,n)
trasparenza = np.random.uniform(0.,1.,n)

fig,ax = plt.subplots(figsize=(10,10))
ax.scatter(x,y,c = colori_stelle, s = dimensione, alpha = trasparenza)
ax.set_facecolor(blu_scuro)
plt.xticks([])
plt.yticks([])
ax.grid(False)
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# ### ES stili

# %%
x = np.linspace(0., 4*np.pi, 100)
s1 = np.sin(x)
s2 = np.cos(x)

# %%
fig, ax = plt.subplots(figsize=(8,4))
ax.plot(x, s1, linestyle = ":", linewidth = 5, color = "red", label = "sin")
ax.plot(x, s2, linestyle = "-.", linewidth = 5, color = "green", label = "cos")
ax.set_xlabel("x", fontsize=20)
ax.set_ylabel("y", fontsize=20)
ax.set_title("Titolo", fontsize = 20)
ax.tick_params(axis="both", labelsize=10)
ax.legend()
ax.grid()
plt.savefig("./grafico.pdf")
plt.show()

# %% [markdown]
# ### Garfici a disperzione

# %%
n_star = 50
x = np.random.uniform(0.,1.,n_star)
y = np.random.uniform(0.,1.,n_star)
colori = np.random.uniform(0.,1.,(n_star,3))
dimensione = np.random.uniform(2., 800., n_star)
trasparenza = np.random.uniform(0.,1., n_star)

# %%
fig, ax = plt.subplots(figsize = (5,5))
ax.scatter(x,y, c = colori, s = dimensione, alpha = trasparenza, marker = "2")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Es cielo stellato a dispersione

# %%
n_star = 50
x = np.random.uniform(0.,1.,n_star)
y = np.random.uniform(0.,1.,n_star)
colori = np.random.uniform(0.,1.,(n_star,3))
dimensione = np.random.uniform(2., 800., n_star)
trasparenza = np.random.uniform(0.,1., n_star)

# %%
fig, ax = plt.subplots(figsize = (5,5))
ax.set_facecolor("black")
ax.scatter(x,y, c = colori, s = dimensione, alpha = trasparenza, marker = "*")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### ES grafico di una matrice

# %%
dati = np.random.normal(0.,1., size=(50,50))

# %%
dati.shape
# Out:
# (50, 50)

# %%
fig, ax = plt.subplots(figsize=(6,6))
ax.imshow(dati, cmap = "hsv")
plt.show()

# %% [markdown]
# ### ES immagine

# %%
os.chdir("Cartella_Immagini")

# %%
immagine = plt.imread("./gatto.jpg")

# %%
fif, ax = plt.subplots(figsize=(4,4))
ax.imshow(immagine)
plt.show()

# %% [markdown]
# ### Es cartella immagini

# %%
os.chdir("Cartella_Immagini")

# %%
immagine1 = plt.imread("./im1.jpg")
immagine2 = plt.imread("./im2.jpg")
immagine3 = plt.imread("./im3.jpg")
immagine4 = plt.imread("./im4.jpg")
L = [immagine1, immagine2, immagine3, immagine4]

# %%
rows = 2
cols = 2
axes=[]
fig=plt.figure()
i = 0

for a in range(rows*cols):
        
    axes.append( fig.add_subplot(rows, cols, a+1) )
    subplot_title=("Immagine "+str(a))
    axes[-1].set_title(subplot_title) 
    plt.imshow(L[i])
    i += 1 
        
fig.tight_layout()    
plt.show()

# %%
path = os.chdir("C:\\Users\\Marco\\Desktop\\5° superiore\\MICROROBOTICA\\Es_Python\\Cartella_Immagini")
lista = os.listdir(path)

# %%
for i in lista:
    fif, ax = plt.subplots(figsize=(3,3))
    immagine = plt.imread(i)
    ax.imshow(immagine)
    plt.show()
    plt.close

# %% [markdown]
# ### Istogrammi

# %%
n_lanci = 10000
dado1 = np.random.randint(1,7,n_lanci)
dado2 = np.random.randint(1,7,n_lanci)
sommaDadi = dado1 + dado2
sommaDadi
# Out:
# array([ 2, 12,  7, ...,  5,  3,  8])

# %%
fig, ax = plt.subplots(figsize=(4,4))
ax.hist(sommaDadi, bins = 11)
plt.show()

# %%
voti = np.random.randint(2,11,100)

# %%
fig, ax = plt.subplots(figsize=(4,4))
ax.hist(voti, bins = 18)
plt.show()

# %% [markdown]
# ### Es con file CSV

# %%
import csv

# %%
dizionario= {}

# %%
file = open("C:\\Users\\Marco\\Desktop\\5° superiore\\MICROROBOTICA\\Es_Python\\Cartella_fileCSV\\penguins_size.csv", "r")
righe = file.readlines()
file.close()

dati = {"species": [], "island" : [], "culmen_length_mm" : [], "culmen_depth_mm" : [], "flipper_length_mm" : [], "body_mass_g" : [], "sex" : [] }

for riga in righe[1:]:
    lista_Campi = riga[:-1].split(",")
    
    if "NA" not in lista_Campi:
        dati["species"].append(lista_Campi[0])
        dati["island"].append(lista_Campi[1])
        dati["culmen_length_mm"].append(float(lista_Campi[2]))
        dati["culmen_depth_mm"].append(float(lista_Campi[3]))
        dati["flipper_length_mm"].append(float(lista_Campi[4]))
        dati["body_mass_g"].append(float(lista_Campi[5]))
        dati["sex"].append(lista_Campi[6])

# %%
for nome_colonna, lista in dati.items():
    dati[nome_colonna] = np.array(lista)

# %%
dati
# Out:
# {'species': array(['Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#         'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#         'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#         'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#         'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#         'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#         'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#         'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#         'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#         'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#         'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#         'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#         'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#         'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
# ...

# %%
fig, ax = plt.subplots(figsize=(5,5))
ax.hist(dati["body_mass_g"])
plt.show()

# %%
fig, ax = plt.subplots(figsize = (5,5))
ax.scatter(dati["body_mass_g"], dati["flipper_length_mm"])
ax.set_xlabel("body_mass_g")
ax.set_ylabel("flipper_lenght_mm")
plt.show()

# %% [markdown]
# ### Sottografici

# %%
fig, axs = plt.subplots(nrows=1 , ncols=2 , figsize = (7,4))
axs[0].hist(dati["body_mass_g"])
axs[0].set_xlabel("body_mass_g")

axs[1].scatter(dati["body_mass_g"], dati["flipper_length_mm"], color = "red", marker= "v")
axs[1].set_xlabel("body_mass_g")
axs[1].set_ylabel("flipper_lenght_mm")

plt.show()

# %% [markdown]
# ## Esercizio punti nel cerchio

# %%
n_punti = 10000
array_X = np.random.uniform(-1,1,n_punti)
array_Y = np.random.uniform(-1,1,n_punti)

# %%
fig, ax = plt.subplots(figsize = (8,8))
ax.scatter(array_X, array_Y, s = 1)
plt.show()

# %%
ipotenusa = np.sqrt(array_X**2+ array_Y**2)
cerchio_x = array_X[ipotenusa <= 1]
cerchio_y = array_Y[ipotenusa <= 1]
colori = np.zeros(n_punti)
colori[ipotenusa <= 1] = 1

# %%
fig, ax = plt.subplots(figsize = (8,8))
ax.scatter(array_X, array_Y, s = 1)
ax.scatter(cerchio_x, cerchio_y, s = 1, c = "red")
plt.show()

# %%
fig, ax = plt.subplots(figsize = (8,8))
ax.scatter(array_X, array_Y, s = 1, c = colori, cmap = "gnuplot")
plt.show()

# %%
Nc = np.count_nonzero(ipotenusa < 1)
Nc
# Out:
# 7844

# %%
pigreco = 4*(Nc/n_punti)
pigreco
# Out:
# 3.1376
