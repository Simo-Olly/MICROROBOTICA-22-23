# %% [markdown]
# # ROBOT IMPAZZITO

# %% [markdown]
#  # ES 1

# %%
# %%timeit
import random 

posizione = 0
numero_secondi = 5 * 24 * 60 * 60
for i in range(numero_secondi):
    posizione += (2 * random.randint(0, 1)) - 1
print(f"Spostamento totale accumulato rispetto alla posizione centrale: {posizione} cm" )
# Out:
# Spostamento totale accumulato rispetto alla posizione centrale: -476 cm
# Spostamento totale accumulato rispetto alla posizione centrale: 552 cm
# Spostamento totale accumulato rispetto alla posizione centrale: -632 cm
# Spostamento totale accumulato rispetto alla posizione centrale: 552 cm
# Spostamento totale accumulato rispetto alla posizione centrale: 898 cm
# Spostamento totale accumulato rispetto alla posizione centrale: 114 cm
# Spostamento totale accumulato rispetto alla posizione centrale: 536 cm
# Spostamento totale accumulato rispetto alla posizione centrale: -1836 cm
# 1.06 s ± 197 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# # ES 2

# %%
import numpy as np

# %%
# %%timeit

numero_secondi = 5 * 24 * 60 * 60
movimenti = np.random.choice([-1,+1], numero_secondi)
posizione = np.sum(movimenti)
print(f"Spostamento totale accumulato rispetto alla poszione centrale: {posizione}cm")
# Out:
# Spostamento totale accumulato rispetto alla poszione centrale: -808cm
# Spostamento totale accumulato rispetto alla poszione centrale: 492cm
# Spostamento totale accumulato rispetto alla poszione centrale: 470cm
# Spostamento totale accumulato rispetto alla poszione centrale: -622cm
# Spostamento totale accumulato rispetto alla poszione centrale: 288cm
# Spostamento totale accumulato rispetto alla poszione centrale: -738cm
# Spostamento totale accumulato rispetto alla poszione centrale: 1024cm
# Spostamento totale accumulato rispetto alla poszione centrale: 618cm
# Spostamento totale accumulato rispetto alla poszione centrale: 684cm
# Spostamento totale accumulato rispetto alla poszione centrale: -270cm
# Spostamento totale accumulato rispetto alla poszione centrale: -1542cm
# Spostamento totale accumulato rispetto alla poszione centrale: -252cm
# Spostamento totale accumulato rispetto alla poszione centrale: 320cm
# Spostamento totale accumulato rispetto alla poszione centrale: 88cm
# Spostamento totale accumulato rispetto alla poszione centrale: -74cm
# Spostamento totale accumulato rispetto alla poszione centrale: 150cm
# Spostamento totale accumulato rispetto alla poszione centrale: -722cm
# Spostamento totale accumulato rispetto alla poszione centrale: -382cm
# Spostamento totale accumulato rispetto alla poszione centrale: -384cm
# Spostamento totale accumulato rispetto alla poszione centrale: -976cm
# Spostamento totale accumulato rispetto alla poszione centrale: 542cm
# Spostamento totale accumulato rispetto alla poszione centrale: -576cm
# Spostamento totale accumulato rispetto alla poszione centrale: -286cm
# Spostamento totale accumulato rispetto alla poszione centrale: -184cm
# Spostamento totale accumulato rispetto alla poszione centrale: 326cm
# Spostamento totale accumulato rispetto alla poszione centrale: -374cm
# Spostamento totale accumulato rispetto alla poszione centrale: -606cm
# Spostamento totale accumulato rispetto alla poszione centrale: 596cm
# Spostamento totale accumulato rispetto alla poszione centrale: 502cm
# Spostamento totale accumulato rispetto alla poszione centrale: 1084cm
# Spostamento totale accumulato rispetto alla poszione centrale: 210cm
# Spostamento totale accumulato rispetto alla poszione centrale: -510cm
# Spostamento totale accumulato rispetto alla poszione centrale: 100cm
# Spostamento totale accumulato rispetto alla poszione centrale: -246cm
# Spostamento totale accumulato rispetto alla poszione centrale: 540cm
# Spostamento totale accumulato rispetto alla poszione centrale: -790cm
# Spostamento totale accumulato rispetto alla poszione centrale: -102cm
# Spostamento totale accumulato rispetto alla poszione centrale: 502cm
# Spostamento totale accumulato rispetto alla poszione centrale: 122cm
# Spostamento totale accumulato rispetto alla poszione centrale: 444cm
# Spostamento totale accumulato rispetto alla poszione centrale: 20cm
# Spostamento totale accumulato rispetto alla poszione centrale: -222cm
# Spostamento totale accumulato rispetto alla poszione centrale: -290cm
# Spostamento totale accumulato rispetto alla poszione centrale: -636cm
# Spostamento totale accumulato rispetto alla poszione centrale: 436cm
# Spostamento totale accumulato rispetto alla poszione centrale: -792cm
# Spostamento totale accumulato rispetto alla poszione centrale: 192cm
# Spostamento totale accumulato rispetto alla poszione centrale: 316cm
# Spostamento totale accumulato rispetto alla poszione centrale: 102cm
# Spostamento totale accumulato rispetto alla poszione centrale: 506cm
# Spostamento totale accumulato rispetto alla poszione centrale: -246cm
# Spostamento totale accumulato rispetto alla poszione centrale: -266cm
# Spostamento totale accumulato rispetto alla poszione centrale: 370cm
# Spostamento totale accumulato rispetto alla poszione centrale: -480cm
# Spostamento totale accumulato rispetto alla poszione centrale: -178cm
# Spostamento totale accumulato rispetto alla poszione centrale: -274cm
# Spostamento totale accumulato rispetto alla poszione centrale: 524cm
# Spostamento totale accumulato rispetto alla poszione centrale: 40cm
# Spostamento totale accumulato rispetto alla poszione centrale: -946cm
# Spostamento totale accumulato rispetto alla poszione centrale: 856cm
# Spostamento totale accumulato rispetto alla poszione centrale: 1534cm
# Spostamento totale accumulato rispetto alla poszione centrale: 658cm
# Spostamento totale accumulato rispetto alla poszione centrale: 164cm
# Spostamento totale accumulato rispetto alla poszione centrale: 1072cm
# Spostamento totale accumulato rispetto alla poszione centrale: -14cm
# Spostamento totale accumulato rispetto alla poszione centrale: -256cm
# Spostamento totale accumulato rispetto alla poszione centrale: -496cm
# Spostamento totale accumulato rispetto alla poszione centrale: 130cm
# Spostamento totale accumulato rispetto alla poszione centrale: -1190cm
# Spostamento totale accumulato rispetto alla poszione centrale: -446cm
# Spostamento totale accumulato rispetto alla poszione centrale: 26cm
# Spostamento totale accumulato rispetto alla poszione centrale: -1174cm
# Spostamento totale accumulato rispetto alla poszione centrale: 506cm
# Spostamento totale accumulato rispetto alla poszione centrale: -528cm
# Spostamento totale accumulato rispetto alla poszione centrale: -612cm
# Spostamento totale accumulato rispetto alla poszione centrale: -294cm
# Spostamento totale accumulato rispetto alla poszione centrale: 418cm
# Spostamento totale accumulato rispetto alla poszione centrale: -702cm
# Spostamento totale accumulato rispetto alla poszione centrale: -388cm
# Spostamento totale accumulato rispetto alla poszione centrale: 228cm
# Spostamento totale accumulato rispetto alla poszione centrale: -478cm
# Spostamento totale accumulato rispetto alla poszione centrale: 942cm
# Spostamento totale accumulato rispetto alla poszione centrale: -262cm
# Spostamento totale accumulato rispetto alla poszione centrale: -46cm
# Spostamento totale accumulato rispetto alla poszione centrale: -146cm
# Spostamento totale accumulato rispetto alla poszione centrale: 64cm
# Spostamento totale accumulato rispetto alla poszione centrale: -544cm
# Spostamento totale accumulato rispetto alla poszione centrale: 450cm
# Spostamento totale accumulato rispetto alla poszione centrale: 504cm
# Spostamento totale accumulato rispetto alla poszione centrale: 14cm
# Spostamento totale accumulato rispetto alla poszione centrale: 558cm
# Spostamento totale accumulato rispetto alla poszione centrale: 362cm
# Spostamento totale accumulato rispetto alla poszione centrale: 138cm
# Spostamento totale accumulato rispetto alla poszione centrale: -248cm
# Spostamento totale accumulato rispetto alla poszione centrale: 122cm
# Spostamento totale accumulato rispetto alla poszione centrale: -1194cm
# Spostamento totale accumulato rispetto alla poszione centrale: -558cm
# Spostamento totale accumulato rispetto alla poszione centrale: -360cm
# Spostamento totale accumulato rispetto alla poszione centrale: 590cm
# Spostamento totale accumulato rispetto alla poszione centrale: -396cm
# Spostamento totale accumulato rispetto alla poszione centrale: -716cm
# Spostamento totale accumulato rispetto alla poszione centrale: -308cm
# Spostamento totale accumulato rispetto alla poszione centrale: -84cm
# Spostamento totale accumulato rispetto alla poszione centrale: 1134cm
# Spostamento totale accumulato rispetto alla poszione centrale: -292cm
# Spostamento totale accumulato rispetto alla poszione centrale: 86cm
# Spostamento totale accumulato rispetto alla poszione centrale: -84cm
# Spostamento totale accumulato rispetto alla poszione centrale: 632cm
# Spostamento totale accumulato rispetto alla poszione centrale: -746cm
# Spostamento totale accumulato rispetto alla poszione centrale: -210cm
# Spostamento totale accumulato rispetto alla poszione centrale: -176cm
# Spostamento totale accumulato rispetto alla poszione centrale: 610cm
# Spostamento totale accumulato rispetto alla poszione centrale: 600cm
# Spostamento totale accumulato rispetto alla poszione centrale: -544cm
# Spostamento totale accumulato rispetto alla poszione centrale: 562cm
# Spostamento totale accumulato rispetto alla poszione centrale: 248cm
# Spostamento totale accumulato rispetto alla poszione centrale: -246cm
# Spostamento totale accumulato rispetto alla poszione centrale: -412cm
# Spostamento totale accumulato rispetto alla poszione centrale: -490cm
# Spostamento totale accumulato rispetto alla poszione centrale: 514cm
# Spostamento totale accumulato rispetto alla poszione centrale: -126cm
# Spostamento totale accumulato rispetto alla poszione centrale: 628cm
# Spostamento totale accumulato rispetto alla poszione centrale: 806cm
# Spostamento totale accumulato rispetto alla poszione centrale: -58cm
# Spostamento totale accumulato rispetto alla poszione centrale: 1552cm
# Spostamento totale accumulato rispetto alla poszione centrale: 208cm
# Spostamento totale accumulato rispetto alla poszione centrale: -324cm
# Spostamento totale accumulato rispetto alla poszione centrale: 462cm
# Spostamento totale accumulato rispetto alla poszione centrale: -668cm
# Spostamento totale accumulato rispetto alla poszione centrale: -32cm
# Spostamento totale accumulato rispetto alla poszione centrale: -1628cm
# Spostamento totale accumulato rispetto alla poszione centrale: 20cm
# Spostamento totale accumulato rispetto alla poszione centrale: -42cm
# Spostamento totale accumulato rispetto alla poszione centrale: 436cm
# Spostamento totale accumulato rispetto alla poszione centrale: -104cm
# Spostamento totale accumulato rispetto alla poszione centrale: -536cm
# Spostamento totale accumulato rispetto alla poszione centrale: -156cm
# Spostamento totale accumulato rispetto alla poszione centrale: 1390cm
# Spostamento totale accumulato rispetto alla poszione centrale: -674cm
# Spostamento totale accumulato rispetto alla poszione centrale: 148cm
# Spostamento totale accumulato rispetto alla poszione centrale: 1210cm
# Spostamento totale accumulato rispetto alla poszione centrale: 28cm
# Spostamento totale accumulato rispetto alla poszione centrale: 102cm
# Spostamento totale accumulato rispetto alla poszione centrale: 304cm
# Spostamento totale accumulato rispetto alla poszione centrale: 44cm
# Spostamento totale accumulato rispetto alla poszione centrale: 672cm
# Spostamento totale accumulato rispetto alla poszione centrale: 744cm
# Spostamento totale accumulato rispetto alla poszione centrale: 82cm
# Spostamento totale accumulato rispetto alla poszione centrale: 532cm
# Spostamento totale accumulato rispetto alla poszione centrale: -24cm
# Spostamento totale accumulato rispetto alla poszione centrale: 90cm
# Spostamento totale accumulato rispetto alla poszione centrale: -56cm
# Spostamento totale accumulato rispetto alla poszione centrale: -448cm
# Spostamento totale accumulato rispetto alla poszione centrale: -252cm
# Spostamento totale accumulato rispetto alla poszione centrale: 1226cm
# Spostamento totale accumulato rispetto alla poszione centrale: -38cm
# Spostamento totale accumulato rispetto alla poszione centrale: 172cm
# Spostamento totale accumulato rispetto alla poszione centrale: 1256cm
# Spostamento totale accumulato rispetto alla poszione centrale: 562cm
# Spostamento totale accumulato rispetto alla poszione centrale: -1272cm
# Spostamento totale accumulato rispetto alla poszione centrale: -282cm
# Spostamento totale accumulato rispetto alla poszione centrale: -932cm
# Spostamento totale accumulato rispetto alla poszione centrale: 410cm
# Spostamento totale accumulato rispetto alla poszione centrale: 1036cm
# Spostamento totale accumulato rispetto alla poszione centrale: -552cm
# Spostamento totale accumulato rispetto alla poszione centrale: -52cm
# Spostamento totale accumulato rispetto alla poszione centrale: 792cm
# Spostamento totale accumulato rispetto alla poszione centrale: 440cm
# Spostamento totale accumulato rispetto alla poszione centrale: 146cm
# Spostamento totale accumulato rispetto alla poszione centrale: -372cm
# Spostamento totale accumulato rispetto alla poszione centrale: 1024cm
# Spostamento totale accumulato rispetto alla poszione centrale: 504cm
# Spostamento totale accumulato rispetto alla poszione centrale: -1046cm
# Spostamento totale accumulato rispetto alla poszione centrale: 696cm
# Spostamento totale accumulato rispetto alla poszione centrale: 46cm
# Spostamento totale accumulato rispetto alla poszione centrale: -608cm
# Spostamento totale accumulato rispetto alla poszione centrale: 76cm
# Spostamento totale accumulato rispetto alla poszione centrale: 486cm
# Spostamento totale accumulato rispetto alla poszione centrale: 1004cm
# Spostamento totale accumulato rispetto alla poszione centrale: -676cm
# Spostamento totale accumulato rispetto alla poszione centrale: -134cm
# Spostamento totale accumulato rispetto alla poszione centrale: -582cm
# Spostamento totale accumulato rispetto alla poszione centrale: 610cm
# Spostamento totale accumulato rispetto alla poszione centrale: -470cm
# Spostamento totale accumulato rispetto alla poszione centrale: -10cm
# Spostamento totale accumulato rispetto alla poszione centrale: 34cm
# Spostamento totale accumulato rispetto alla poszione centrale: -432cm
# Spostamento totale accumulato rispetto alla poszione centrale: -1086cm
# Spostamento totale accumulato rispetto alla poszione centrale: 164cm
# Spostamento totale accumulato rispetto alla poszione centrale: 386cm
# Spostamento totale accumulato rispetto alla poszione centrale: -2cm
# Spostamento totale accumulato rispetto alla poszione centrale: -984cm
# Spostamento totale accumulato rispetto alla poszione centrale: -776cm
# Spostamento totale accumulato rispetto alla poszione centrale: -128cm
# Spostamento totale accumulato rispetto alla poszione centrale: -398cm
# Spostamento totale accumulato rispetto alla poszione centrale: 36cm
# Spostamento totale accumulato rispetto alla poszione centrale: -1622cm
# Spostamento totale accumulato rispetto alla poszione centrale: 984cm
# Spostamento totale accumulato rispetto alla poszione centrale: 906cm
# Spostamento totale accumulato rispetto alla poszione centrale: -304cm
# Spostamento totale accumulato rispetto alla poszione centrale: 492cm
# Spostamento totale accumulato rispetto alla poszione centrale: 346cm
# Spostamento totale accumulato rispetto alla poszione centrale: -1002cm
# Spostamento totale accumulato rispetto alla poszione centrale: -568cm
# Spostamento totale accumulato rispetto alla poszione centrale: -814cm
# Spostamento totale accumulato rispetto alla poszione centrale: -764cm
# Spostamento totale accumulato rispetto alla poszione centrale: -324cm
# Spostamento totale accumulato rispetto alla poszione centrale: 1248cm
# Spostamento totale accumulato rispetto alla poszione centrale: -440cm
# Spostamento totale accumulato rispetto alla poszione centrale: -742cm
# Spostamento totale accumulato rispetto alla poszione centrale: -854cm
# Spostamento totale accumulato rispetto alla poszione centrale: -386cm
# Spostamento totale accumulato rispetto alla poszione centrale: 924cm
# Spostamento totale accumulato rispetto alla poszione centrale: 572cm
# Spostamento totale accumulato rispetto alla poszione centrale: -628cm
# Spostamento totale accumulato rispetto alla poszione centrale: 416cm
# Spostamento totale accumulato rispetto alla poszione centrale: -210cm
# Spostamento totale accumulato rispetto alla poszione centrale: -514cm
# Spostamento totale accumulato rispetto alla poszione centrale: 1430cm
# Spostamento totale accumulato rispetto alla poszione centrale: 576cm
# Spostamento totale accumulato rispetto alla poszione centrale: 78cm
# Spostamento totale accumulato rispetto alla poszione centrale: -450cm
# Spostamento totale accumulato rispetto alla poszione centrale: 438cm
# Spostamento totale accumulato rispetto alla poszione centrale: -66cm
# Spostamento totale accumulato rispetto alla poszione centrale: 810cm
# Spostamento totale accumulato rispetto alla poszione centrale: -2cm
# Spostamento totale accumulato rispetto alla poszione centrale: -322cm
# Spostamento totale accumulato rispetto alla poszione centrale: 218cm
# Spostamento totale accumulato rispetto alla poszione centrale: -240cm
# Spostamento totale accumulato rispetto alla poszione centrale: -842cm
# Spostamento totale accumulato rispetto alla poszione centrale: -616cm
# Spostamento totale accumulato rispetto alla poszione centrale: 778cm
# Spostamento totale accumulato rispetto alla poszione centrale: 1314cm
# Spostamento totale accumulato rispetto alla poszione centrale: -490cm
# Spostamento totale accumulato rispetto alla poszione centrale: 540cm
# Spostamento totale accumulato rispetto alla poszione centrale: 816cm
# Spostamento totale accumulato rispetto alla poszione centrale: 148cm
# Spostamento totale accumulato rispetto alla poszione centrale: -268cm
# Spostamento totale accumulato rispetto alla poszione centrale: 90cm
# Spostamento totale accumulato rispetto alla poszione centrale: -564cm
# Spostamento totale accumulato rispetto alla poszione centrale: 482cm
# Spostamento totale accumulato rispetto alla poszione centrale: 752cm
# Spostamento totale accumulato rispetto alla poszione centrale: 370cm
# Spostamento totale accumulato rispetto alla poszione centrale: 192cm
# Spostamento totale accumulato rispetto alla poszione centrale: 840cm
# Spostamento totale accumulato rispetto alla poszione centrale: 56cm
# Spostamento totale accumulato rispetto alla poszione centrale: 506cm
# Spostamento totale accumulato rispetto alla poszione centrale: 998cm
# Spostamento totale accumulato rispetto alla poszione centrale: -454cm
# Spostamento totale accumulato rispetto alla poszione centrale: 60cm
# Spostamento totale accumulato rispetto alla poszione centrale: 272cm
# Spostamento totale accumulato rispetto alla poszione centrale: 186cm
# Spostamento totale accumulato rispetto alla poszione centrale: -288cm
# Spostamento totale accumulato rispetto alla poszione centrale: 316cm
# Spostamento totale accumulato rispetto alla poszione centrale: -322cm
# Spostamento totale accumulato rispetto alla poszione centrale: -606cm
# Spostamento totale accumulato rispetto alla poszione centrale: -236cm
# Spostamento totale accumulato rispetto alla poszione centrale: 510cm
# Spostamento totale accumulato rispetto alla poszione centrale: -186cm
# Spostamento totale accumulato rispetto alla poszione centrale: -112cm
# Spostamento totale accumulato rispetto alla poszione centrale: 1094cm
# Spostamento totale accumulato rispetto alla poszione centrale: 264cm
# Spostamento totale accumulato rispetto alla poszione centrale: -870cm
# Spostamento totale accumulato rispetto alla poszione centrale: 232cm
# Spostamento totale accumulato rispetto alla poszione centrale: 414cm
# Spostamento totale accumulato rispetto alla poszione centrale: -246cm
# Spostamento totale accumulato rispetto alla poszione centrale: -138cm
# Spostamento totale accumulato rispetto alla poszione centrale: 408cm
# Spostamento totale accumulato rispetto alla poszione centrale: -52cm
# Spostamento totale accumulato rispetto alla poszione centrale: -38cm
# Spostamento totale accumulato rispetto alla poszione centrale: -670cm
# Spostamento totale accumulato rispetto alla poszione centrale: 706cm
# Spostamento totale accumulato rispetto alla poszione centrale: 380cm
# Spostamento totale accumulato rispetto alla poszione centrale: -618cm
# Spostamento totale accumulato rispetto alla poszione centrale: 810cm
# Spostamento totale accumulato rispetto alla poszione centrale: -1178cm
# Spostamento totale accumulato rispetto alla poszione centrale: 264cm
# Spostamento totale accumulato rispetto alla poszione centrale: -48cm
# Spostamento totale accumulato rispetto alla poszione centrale: -544cm
# Spostamento totale accumulato rispetto alla poszione centrale: 632cm
# Spostamento totale accumulato rispetto alla poszione centrale: -662cm
# Spostamento totale accumulato rispetto alla poszione centrale: 158cm
# Spostamento totale accumulato rispetto alla poszione centrale: 232cm
# Spostamento totale accumulato rispetto alla poszione centrale: 500cm
# Spostamento totale accumulato rispetto alla poszione centrale: -92cm
# Spostamento totale accumulato rispetto alla poszione centrale: -160cm
# Spostamento totale accumulato rispetto alla poszione centrale: 410cm
# Spostamento totale accumulato rispetto alla poszione centrale: 1332cm
# Spostamento totale accumulato rispetto alla poszione centrale: -1162cm
# Spostamento totale accumulato rispetto alla poszione centrale: 896cm
# Spostamento totale accumulato rispetto alla poszione centrale: -680cm
# Spostamento totale accumulato rispetto alla poszione centrale: 410cm
# Spostamento totale accumulato rispetto alla poszione centrale: 524cm
# Spostamento totale accumulato rispetto alla poszione centrale: 438cm
# Spostamento totale accumulato rispetto alla poszione centrale: 14cm
# Spostamento totale accumulato rispetto alla poszione centrale: -70cm
# Spostamento totale accumulato rispetto alla poszione centrale: -796cm
# Spostamento totale accumulato rispetto alla poszione centrale: 986cm
# Spostamento totale accumulato rispetto alla poszione centrale: -346cm
# Spostamento totale accumulato rispetto alla poszione centrale: 582cm
# Spostamento totale accumulato rispetto alla poszione centrale: 614cm
# Spostamento totale accumulato rispetto alla poszione centrale: -258cm
# Spostamento totale accumulato rispetto alla poszione centrale: 276cm
# Spostamento totale accumulato rispetto alla poszione centrale: -508cm
# Spostamento totale accumulato rispetto alla poszione centrale: -154cm
# Spostamento totale accumulato rispetto alla poszione centrale: 216cm
# Spostamento totale accumulato rispetto alla poszione centrale: -586cm
# Spostamento totale accumulato rispetto alla poszione centrale: 332cm
# Spostamento totale accumulato rispetto alla poszione centrale: 84cm
# Spostamento totale accumulato rispetto alla poszione centrale: 778cm
# Spostamento totale accumulato rispetto alla poszione centrale: -750cm
# Spostamento totale accumulato rispetto alla poszione centrale: 458cm
# Spostamento totale accumulato rispetto alla poszione centrale: 546cm
# Spostamento totale accumulato rispetto alla poszione centrale: 118cm
# Spostamento totale accumulato rispetto alla poszione centrale: 1484cm
# Spostamento totale accumulato rispetto alla poszione centrale: 724cm
# Spostamento totale accumulato rispetto alla poszione centrale: -770cm
# Spostamento totale accumulato rispetto alla poszione centrale: 450cm
# Spostamento totale accumulato rispetto alla poszione centrale: 382cm
# Spostamento totale accumulato rispetto alla poszione centrale: 12cm
# Spostamento totale accumulato rispetto alla poszione centrale: 84cm
# Spostamento totale accumulato rispetto alla poszione centrale: 692cm
# Spostamento totale accumulato rispetto alla poszione centrale: -652cm
# Spostamento totale accumulato rispetto alla poszione centrale: 86cm
# Spostamento totale accumulato rispetto alla poszione centrale: -356cm
# Spostamento totale accumulato rispetto alla poszione centrale: -1438cm
# Spostamento totale accumulato rispetto alla poszione centrale: 430cm
# Spostamento totale accumulato rispetto alla poszione centrale: 416cm
# Spostamento totale accumulato rispetto alla poszione centrale: 482cm
# Spostamento totale accumulato rispetto alla poszione centrale: -76cm
# Spostamento totale accumulato rispetto alla poszione centrale: 468cm
# Spostamento totale accumulato rispetto alla poszione centrale: 1344cm
# Spostamento totale accumulato rispetto alla poszione centrale: 490cm
# Spostamento totale accumulato rispetto alla poszione centrale: -844cm
# Spostamento totale accumulato rispetto alla poszione centrale: -112cm
# Spostamento totale accumulato rispetto alla poszione centrale: -320cm
# Spostamento totale accumulato rispetto alla poszione centrale: 362cm
# Spostamento totale accumulato rispetto alla poszione centrale: -410cm
# Spostamento totale accumulato rispetto alla poszione centrale: -204cm
# Spostamento totale accumulato rispetto alla poszione centrale: -250cm
# Spostamento totale accumulato rispetto alla poszione centrale: -988cm
# Spostamento totale accumulato rispetto alla poszione centrale: -558cm
# Spostamento totale accumulato rispetto alla poszione centrale: 194cm
# Spostamento totale accumulato rispetto alla poszione centrale: 156cm
# Spostamento totale accumulato rispetto alla poszione centrale: -346cm
# Spostamento totale accumulato rispetto alla poszione centrale: 404cm
# Spostamento totale accumulato rispetto alla poszione centrale: -162cm
# Spostamento totale accumulato rispetto alla poszione centrale: 432cm
# Spostamento totale accumulato rispetto alla poszione centrale: -750cm
# Spostamento totale accumulato rispetto alla poszione centrale: -842cm
# Spostamento totale accumulato rispetto alla poszione centrale: -1116cm
# Spostamento totale accumulato rispetto alla poszione centrale: -1406cm
# Spostamento totale accumulato rispetto alla poszione centrale: 306cm
# Spostamento totale accumulato rispetto alla poszione centrale: 812cm
# Spostamento totale accumulato rispetto alla poszione centrale: -716cm
# Spostamento totale accumulato rispetto alla poszione centrale: -696cm
# Spostamento totale accumulato rispetto alla poszione centrale: -630cm
# Spostamento totale accumulato rispetto alla poszione centrale: 418cm
# Spostamento totale accumulato rispetto alla poszione centrale: 514cm
# Spostamento totale accumulato rispetto alla poszione centrale: 464cm
# Spostamento totale accumulato rispetto alla poszione centrale: 104cm
# Spostamento totale accumulato rispetto alla poszione centrale: -616cm
# Spostamento totale accumulato rispetto alla poszione centrale: -536cm
# Spostamento totale accumulato rispetto alla poszione centrale: -52cm
# Spostamento totale accumulato rispetto alla poszione centrale: -410cm
# Spostamento totale accumulato rispetto alla poszione centrale: -82cm
# Spostamento totale accumulato rispetto alla poszione centrale: 756cm
# Spostamento totale accumulato rispetto alla poszione centrale: -544cm
# Spostamento totale accumulato rispetto alla poszione centrale: -168cm
# Spostamento totale accumulato rispetto alla poszione centrale: -468cm
# Spostamento totale accumulato rispetto alla poszione centrale: -212cm
# Spostamento totale accumulato rispetto alla poszione centrale: 118cm
# Spostamento totale accumulato rispetto alla poszione centrale: 126cm
# Spostamento totale accumulato rispetto alla poszione centrale: 280cm
# Spostamento totale accumulato rispetto alla poszione centrale: 346cm
# Spostamento totale accumulato rispetto alla poszione centrale: 108cm
# Spostamento totale accumulato rispetto alla poszione centrale: -38cm
# Spostamento totale accumulato rispetto alla poszione centrale: -78cm
# Spostamento totale accumulato rispetto alla poszione centrale: 192cm
# Spostamento totale accumulato rispetto alla poszione centrale: -80cm
# Spostamento totale accumulato rispetto alla poszione centrale: -334cm
# Spostamento totale accumulato rispetto alla poszione centrale: -348cm
# Spostamento totale accumulato rispetto alla poszione centrale: -406cm
# Spostamento totale accumulato rispetto alla poszione centrale: -1278cm
# Spostamento totale accumulato rispetto alla poszione centrale: -162cm
# Spostamento totale accumulato rispetto alla poszione centrale: 338cm
# Spostamento totale accumulato rispetto alla poszione centrale: 384cm
# Spostamento totale accumulato rispetto alla poszione centrale: -494cm
# Spostamento totale accumulato rispetto alla poszione centrale: 84cm
# Spostamento totale accumulato rispetto alla poszione centrale: 362cm
# Spostamento totale accumulato rispetto alla poszione centrale: 720cm
# Spostamento totale accumulato rispetto alla poszione centrale: -1626cm
# Spostamento totale accumulato rispetto alla poszione centrale: -18cm
# Spostamento totale accumulato rispetto alla poszione centrale: -308cm
# Spostamento totale accumulato rispetto alla poszione centrale: -178cm
# Spostamento totale accumulato rispetto alla poszione centrale: 618cm
# Spostamento totale accumulato rispetto alla poszione centrale: 578cm
# Spostamento totale accumulato rispetto alla poszione centrale: 986cm
# Spostamento totale accumulato rispetto alla poszione centrale: 714cm
# Spostamento totale accumulato rispetto alla poszione centrale: 412cm
# Spostamento totale accumulato rispetto alla poszione centrale: 534cm
# Spostamento totale accumulato rispetto alla poszione centrale: -1210cm
# Spostamento totale accumulato rispetto alla poszione centrale: 252cm
# Spostamento totale accumulato rispetto alla poszione centrale: -258cm
# Spostamento totale accumulato rispetto alla poszione centrale: 1054cm
# Spostamento totale accumulato rispetto alla poszione centrale: 342cm
# Spostamento totale accumulato rispetto alla poszione centrale: 608cm
# Spostamento totale accumulato rispetto alla poszione centrale: 792cm
# Spostamento totale accumulato rispetto alla poszione centrale: 1536cm
# Spostamento totale accumulato rispetto alla poszione centrale: -1178cm
# Spostamento totale accumulato rispetto alla poszione centrale: 922cm
# Spostamento totale accumulato rispetto alla poszione centrale: 364cm
# Spostamento totale accumulato rispetto alla poszione centrale: 344cm
# Spostamento totale accumulato rispetto alla poszione centrale: -22cm
# Spostamento totale accumulato rispetto alla poszione centrale: 434cm
# Spostamento totale accumulato rispetto alla poszione centrale: -252cm
# Spostamento totale accumulato rispetto alla poszione centrale: 946cm
# Spostamento totale accumulato rispetto alla poszione centrale: -610cm
# Spostamento totale accumulato rispetto alla poszione centrale: 714cm
# Spostamento totale accumulato rispetto alla poszione centrale: 1156cm
# Spostamento totale accumulato rispetto alla poszione centrale: -354cm
# Spostamento totale accumulato rispetto alla poszione centrale: -598cm
# Spostamento totale accumulato rispetto alla poszione centrale: -744cm
# Spostamento totale accumulato rispetto alla poszione centrale: -1356cm
# Spostamento totale accumulato rispetto alla poszione centrale: -418cm
# Spostamento totale accumulato rispetto alla poszione centrale: -348cm
# Spostamento totale accumulato rispetto alla poszione centrale: 88cm
# Spostamento totale accumulato rispetto alla poszione centrale: -466cm
# Spostamento totale accumulato rispetto alla poszione centrale: -144cm
# Spostamento totale accumulato rispetto alla poszione centrale: -1238cm
# Spostamento totale accumulato rispetto alla poszione centrale: -684cm
# Spostamento totale accumulato rispetto alla poszione centrale: -48cm
# Spostamento totale accumulato rispetto alla poszione centrale: 402cm
# Spostamento totale accumulato rispetto alla poszione centrale: 512cm
# Spostamento totale accumulato rispetto alla poszione centrale: 1180cm
# Spostamento totale accumulato rispetto alla poszione centrale: 1288cm
# Spostamento totale accumulato rispetto alla poszione centrale: -370cm
# Spostamento totale accumulato rispetto alla poszione centrale: 160cm
# Spostamento totale accumulato rispetto alla poszione centrale: 10cm
# Spostamento totale accumulato rispetto alla poszione centrale: -1494cm
# Spostamento totale accumulato rispetto alla poszione centrale: 258cm
# Spostamento totale accumulato rispetto alla poszione centrale: -376cm
# Spostamento totale accumulato rispetto alla poszione centrale: 602cm
# Spostamento totale accumulato rispetto alla poszione centrale: 294cm
# Spostamento totale accumulato rispetto alla poszione centrale: -692cm
# Spostamento totale accumulato rispetto alla poszione centrale: 656cm
# Spostamento totale accumulato rispetto alla poszione centrale: 436cm
# Spostamento totale accumulato rispetto alla poszione centrale: -1062cm
# Spostamento totale accumulato rispetto alla poszione centrale: 1108cm
# Spostamento totale accumulato rispetto alla poszione centrale: -98cm
# Spostamento totale accumulato rispetto alla poszione centrale: 84cm
# Spostamento totale accumulato rispetto alla poszione centrale: 264cm
# Spostamento totale accumulato rispetto alla poszione centrale: -64cm
# Spostamento totale accumulato rispetto alla poszione centrale: 870cm
# Spostamento totale accumulato rispetto alla poszione centrale: 272cm
# Spostamento totale accumulato rispetto alla poszione centrale: -388cm
# Spostamento totale accumulato rispetto alla poszione centrale: -1372cm
# Spostamento totale accumulato rispetto alla poszione centrale: -292cm
# Spostamento totale accumulato rispetto alla poszione centrale: -566cm
# Spostamento totale accumulato rispetto alla poszione centrale: -1292cm
# Spostamento totale accumulato rispetto alla poszione centrale: -22cm
# Spostamento totale accumulato rispetto alla poszione centrale: 0cm
# Spostamento totale accumulato rispetto alla poszione centrale: 798cm
# Spostamento totale accumulato rispetto alla poszione centrale: 1040cm
# Spostamento totale accumulato rispetto alla poszione centrale: -758cm
# Spostamento totale accumulato rispetto alla poszione centrale: -420cm
# Spostamento totale accumulato rispetto alla poszione centrale: 122cm
# Spostamento totale accumulato rispetto alla poszione centrale: -802cm
# Spostamento totale accumulato rispetto alla poszione centrale: -152cm
# Spostamento totale accumulato rispetto alla poszione centrale: 818cm
# Spostamento totale accumulato rispetto alla poszione centrale: 196cm
# Spostamento totale accumulato rispetto alla poszione centrale: -104cm
# Spostamento totale accumulato rispetto alla poszione centrale: 660cm
# Spostamento totale accumulato rispetto alla poszione centrale: 42cm
# Spostamento totale accumulato rispetto alla poszione centrale: 610cm
# Spostamento totale accumulato rispetto alla poszione centrale: 14cm
# Spostamento totale accumulato rispetto alla poszione centrale: 1402cm
# Spostamento totale accumulato rispetto alla poszione centrale: -410cm
# Spostamento totale accumulato rispetto alla poszione centrale: 502cm
# Spostamento totale accumulato rispetto alla poszione centrale: 370cm
# Spostamento totale accumulato rispetto alla poszione centrale: -536cm
# Spostamento totale accumulato rispetto alla poszione centrale: -348cm
# Spostamento totale accumulato rispetto alla poszione centrale: -648cm
# Spostamento totale accumulato rispetto alla poszione centrale: -480cm
# Spostamento totale accumulato rispetto alla poszione centrale: -376cm
# Spostamento totale accumulato rispetto alla poszione centrale: -66cm
# Spostamento totale accumulato rispetto alla poszione centrale: -60cm
# Spostamento totale accumulato rispetto alla poszione centrale: -488cm
# Spostamento totale accumulato rispetto alla poszione centrale: -220cm
# Spostamento totale accumulato rispetto alla poszione centrale: -150cm
# Spostamento totale accumulato rispetto alla poszione centrale: 10cm
# Spostamento totale accumulato rispetto alla poszione centrale: 126cm
# Spostamento totale accumulato rispetto alla poszione centrale: 1020cm
# Spostamento totale accumulato rispetto alla poszione centrale: 738cm
# Spostamento totale accumulato rispetto alla poszione centrale: -446cm
# Spostamento totale accumulato rispetto alla poszione centrale: 722cm
# Spostamento totale accumulato rispetto alla poszione centrale: -252cm
# Spostamento totale accumulato rispetto alla poszione centrale: 366cm
# Spostamento totale accumulato rispetto alla poszione centrale: 172cm
# Spostamento totale accumulato rispetto alla poszione centrale: 612cm
# Spostamento totale accumulato rispetto alla poszione centrale: 430cm
# Spostamento totale accumulato rispetto alla poszione centrale: -1288cm
# Spostamento totale accumulato rispetto alla poszione centrale: -134cm
# Spostamento totale accumulato rispetto alla poszione centrale: -270cm
# Spostamento totale accumulato rispetto alla poszione centrale: -1288cm
# Spostamento totale accumulato rispetto alla poszione centrale: -1012cm
# Spostamento totale accumulato rispetto alla poszione centrale: 464cm
# Spostamento totale accumulato rispetto alla poszione centrale: -914cm
# Spostamento totale accumulato rispetto alla poszione centrale: -670cm
# Spostamento totale accumulato rispetto alla poszione centrale: -188cm
# Spostamento totale accumulato rispetto alla poszione centrale: -136cm
# Spostamento totale accumulato rispetto alla poszione centrale: -504cm
# Spostamento totale accumulato rispetto alla poszione centrale: -200cm
# Spostamento totale accumulato rispetto alla poszione centrale: 964cm
# Spostamento totale accumulato rispetto alla poszione centrale: 318cm
# Spostamento totale accumulato rispetto alla poszione centrale: -668cm
# Spostamento totale accumulato rispetto alla poszione centrale: -124cm
# Spostamento totale accumulato rispetto alla poszione centrale: -606cm
# Spostamento totale accumulato rispetto alla poszione centrale: 442cm
# Spostamento totale accumulato rispetto alla poszione centrale: 132cm
# Spostamento totale accumulato rispetto alla poszione centrale: 182cm
# Spostamento totale accumulato rispetto alla poszione centrale: 650cm
# Spostamento totale accumulato rispetto alla poszione centrale: -652cm
# Spostamento totale accumulato rispetto alla poszione centrale: 712cm
# Spostamento totale accumulato rispetto alla poszione centrale: 362cm
# Spostamento totale accumulato rispetto alla poszione centrale: 1108cm
# Spostamento totale accumulato rispetto alla poszione centrale: -842cm
# Spostamento totale accumulato rispetto alla poszione centrale: -178cm
# Spostamento totale accumulato rispetto alla poszione centrale: -510cm
# Spostamento totale accumulato rispetto alla poszione centrale: 454cm
# Spostamento totale accumulato rispetto alla poszione centrale: 694cm
# Spostamento totale accumulato rispetto alla poszione centrale: -624cm
# Spostamento totale accumulato rispetto alla poszione centrale: 1576cm
# Spostamento totale accumulato rispetto alla poszione centrale: 312cm
# Spostamento totale accumulato rispetto alla poszione centrale: -1052cm
# Spostamento totale accumulato rispetto alla poszione centrale: 170cm
# Spostamento totale accumulato rispetto alla poszione centrale: 218cm
# Spostamento totale accumulato rispetto alla poszione centrale: 136cm
# Spostamento totale accumulato rispetto alla poszione centrale: -1018cm
# Spostamento totale accumulato rispetto alla poszione centrale: 668cm
# Spostamento totale accumulato rispetto alla poszione centrale: 548cm
# Spostamento totale accumulato rispetto alla poszione centrale: -380cm
# Spostamento totale accumulato rispetto alla poszione centrale: 766cm
# Spostamento totale accumulato rispetto alla poszione centrale: -466cm
# Spostamento totale accumulato rispetto alla poszione centrale: 128cm
# Spostamento totale accumulato rispetto alla poszione centrale: 600cm
# Spostamento totale accumulato rispetto alla poszione centrale: 264cm
# Spostamento totale accumulato rispetto alla poszione centrale: -286cm
# Spostamento totale accumulato rispetto alla poszione centrale: -1266cm
# Spostamento totale accumulato rispetto alla poszione centrale: -174cm
# Spostamento totale accumulato rispetto alla poszione centrale: -546cm
# Spostamento totale accumulato rispetto alla poszione centrale: -56cm
# Spostamento totale accumulato rispetto alla poszione centrale: -454cm
# Spostamento totale accumulato rispetto alla poszione centrale: 446cm
# Spostamento totale accumulato rispetto alla poszione centrale: -134cm
# Spostamento totale accumulato rispetto alla poszione centrale: 206cm
# Spostamento totale accumulato rispetto alla poszione centrale: -418cm
# Spostamento totale accumulato rispetto alla poszione centrale: -274cm
# Spostamento totale accumulato rispetto alla poszione centrale: -662cm
# Spostamento totale accumulato rispetto alla poszione centrale: -680cm
# Spostamento totale accumulato rispetto alla poszione centrale: 1086cm
# Spostamento totale accumulato rispetto alla poszione centrale: 330cm
# Spostamento totale accumulato rispetto alla poszione centrale: 190cm
# Spostamento totale accumulato rispetto alla poszione centrale: -460cm
# Spostamento totale accumulato rispetto alla poszione centrale: -816cm
# Spostamento totale accumulato rispetto alla poszione centrale: -32cm
# Spostamento totale accumulato rispetto alla poszione centrale: -226cm
# Spostamento totale accumulato rispetto alla poszione centrale: 464cm
# Spostamento totale accumulato rispetto alla poszione centrale: -1208cm
# Spostamento totale accumulato rispetto alla poszione centrale: -424cm
# Spostamento totale accumulato rispetto alla poszione centrale: 2cm
# Spostamento totale accumulato rispetto alla poszione centrale: -590cm
# Spostamento totale accumulato rispetto alla poszione centrale: 530cm
# Spostamento totale accumulato rispetto alla poszione centrale: -512cm
# Spostamento totale accumulato rispetto alla poszione centrale: 1162cm
# Spostamento totale accumulato rispetto alla poszione centrale: 232cm
# Spostamento totale accumulato rispetto alla poszione centrale: 782cm
# Spostamento totale accumulato rispetto alla poszione centrale: 314cm
# Spostamento totale accumulato rispetto alla poszione centrale: -586cm
# Spostamento totale accumulato rispetto alla poszione centrale: 624cm
# Spostamento totale accumulato rispetto alla poszione centrale: -62cm
# Spostamento totale accumulato rispetto alla poszione centrale: 1140cm
# Spostamento totale accumulato rispetto alla poszione centrale: -768cm
# Spostamento totale accumulato rispetto alla poszione centrale: 390cm
# Spostamento totale accumulato rispetto alla poszione centrale: -1124cm
# Spostamento totale accumulato rispetto alla poszione centrale: 344cm
# Spostamento totale accumulato rispetto alla poszione centrale: -756cm
# Spostamento totale accumulato rispetto alla poszione centrale: -862cm
# Spostamento totale accumulato rispetto alla poszione centrale: 316cm
# Spostamento totale accumulato rispetto alla poszione centrale: -512cm
# Spostamento totale accumulato rispetto alla poszione centrale: 178cm
# Spostamento totale accumulato rispetto alla poszione centrale: -350cm
# Spostamento totale accumulato rispetto alla poszione centrale: -62cm
# Spostamento totale accumulato rispetto alla poszione centrale: -384cm
# Spostamento totale accumulato rispetto alla poszione centrale: 552cm
# Spostamento totale accumulato rispetto alla poszione centrale: -352cm
# Spostamento totale accumulato rispetto alla poszione centrale: 538cm
# Spostamento totale accumulato rispetto alla poszione centrale: 48cm
# Spostamento totale accumulato rispetto alla poszione centrale: 824cm
# Spostamento totale accumulato rispetto alla poszione centrale: 124cm
# Spostamento totale accumulato rispetto alla poszione centrale: -1238cm
# Spostamento totale accumulato rispetto alla poszione centrale: -194cm
# Spostamento totale accumulato rispetto alla poszione centrale: 404cm
# Spostamento totale accumulato rispetto alla poszione centrale: 426cm
# Spostamento totale accumulato rispetto alla poszione centrale: 966cm
# Spostamento totale accumulato rispetto alla poszione centrale: -1238cm
# Spostamento totale accumulato rispetto alla poszione centrale: -456cm
# Spostamento totale accumulato rispetto alla poszione centrale: -972cm
# Spostamento totale accumulato rispetto alla poszione centrale: 744cm
# Spostamento totale accumulato rispetto alla poszione centrale: -320cm
# Spostamento totale accumulato rispetto alla poszione centrale: 718cm
# Spostamento totale accumulato rispetto alla poszione centrale: 192cm
# Spostamento totale accumulato rispetto alla poszione centrale: -292cm
# Spostamento totale accumulato rispetto alla poszione centrale: 1470cm
# Spostamento totale accumulato rispetto alla poszione centrale: 666cm
# Spostamento totale accumulato rispetto alla poszione centrale: -1114cm
# Spostamento totale accumulato rispetto alla poszione centrale: -768cm
# Spostamento totale accumulato rispetto alla poszione centrale: -188cm
# Spostamento totale accumulato rispetto alla poszione centrale: 1208cm
# Spostamento totale accumulato rispetto alla poszione centrale: -632cm
# Spostamento totale accumulato rispetto alla poszione centrale: 558cm
# Spostamento totale accumulato rispetto alla poszione centrale: 226cm
# Spostamento totale accumulato rispetto alla poszione centrale: -902cm
# Spostamento totale accumulato rispetto alla poszione centrale: -878cm
# Spostamento totale accumulato rispetto alla poszione centrale: 4cm
# Spostamento totale accumulato rispetto alla poszione centrale: -44cm
# Spostamento totale accumulato rispetto alla poszione centrale: 104cm
# Spostamento totale accumulato rispetto alla poszione centrale: -854cm
# Spostamento totale accumulato rispetto alla poszione centrale: -732cm
# Spostamento totale accumulato rispetto alla poszione centrale: 74cm
# Spostamento totale accumulato rispetto alla poszione centrale: 540cm
# Spostamento totale accumulato rispetto alla poszione centrale: 1398cm
# Spostamento totale accumulato rispetto alla poszione centrale: -182cm
# Spostamento totale accumulato rispetto alla poszione centrale: 178cm
# Spostamento totale accumulato rispetto alla poszione centrale: 136cm
# Spostamento totale accumulato rispetto alla poszione centrale: -948cm
# Spostamento totale accumulato rispetto alla poszione centrale: 578cm
# Spostamento totale accumulato rispetto alla poszione centrale: -746cm
# Spostamento totale accumulato rispetto alla poszione centrale: 524cm
# Spostamento totale accumulato rispetto alla poszione centrale: -250cm
# Spostamento totale accumulato rispetto alla poszione centrale: 794cm
# Spostamento totale accumulato rispetto alla poszione centrale: -488cm
# Spostamento totale accumulato rispetto alla poszione centrale: -232cm
# Spostamento totale accumulato rispetto alla poszione centrale: -334cm
# Spostamento totale accumulato rispetto alla poszione centrale: 18cm
# Spostamento totale accumulato rispetto alla poszione centrale: 402cm
# Spostamento totale accumulato rispetto alla poszione centrale: -366cm
# Spostamento totale accumulato rispetto alla poszione centrale: 958cm
# Spostamento totale accumulato rispetto alla poszione centrale: -98cm
# Spostamento totale accumulato rispetto alla poszione centrale: -548cm
# Spostamento totale accumulato rispetto alla poszione centrale: -462cm
# Spostamento totale accumulato rispetto alla poszione centrale: -722cm
# Spostamento totale accumulato rispetto alla poszione centrale: 954cm
# Spostamento totale accumulato rispetto alla poszione centrale: -990cm
# Spostamento totale accumulato rispetto alla poszione centrale: 452cm
# Spostamento totale accumulato rispetto alla poszione centrale: -98cm
# Spostamento totale accumulato rispetto alla poszione centrale: -232cm
# Spostamento totale accumulato rispetto alla poszione centrale: -20cm
# Spostamento totale accumulato rispetto alla poszione centrale: 66cm
# Spostamento totale accumulato rispetto alla poszione centrale: -744cm
# Spostamento totale accumulato rispetto alla poszione centrale: 1146cm
# Spostamento totale accumulato rispetto alla poszione centrale: 254cm
# Spostamento totale accumulato rispetto alla poszione centrale: 176cm
# Spostamento totale accumulato rispetto alla poszione centrale: 442cm
# Spostamento totale accumulato rispetto alla poszione centrale: 76cm
# Spostamento totale accumulato rispetto alla poszione centrale: 410cm
# Spostamento totale accumulato rispetto alla poszione centrale: 112cm
# Spostamento totale accumulato rispetto alla poszione centrale: -846cm
# Spostamento totale accumulato rispetto alla poszione centrale: -270cm
# Spostamento totale accumulato rispetto alla poszione centrale: 262cm
# Spostamento totale accumulato rispetto alla poszione centrale: -692cm
# Spostamento totale accumulato rispetto alla poszione centrale: -884cm
# Spostamento totale accumulato rispetto alla poszione centrale: 634cm
# Spostamento totale accumulato rispetto alla poszione centrale: 670cm
# Spostamento totale accumulato rispetto alla poszione centrale: -416cm
# Spostamento totale accumulato rispetto alla poszione centrale: 114cm
# Spostamento totale accumulato rispetto alla poszione centrale: -116cm
# Spostamento totale accumulato rispetto alla poszione centrale: -40cm
# Spostamento totale accumulato rispetto alla poszione centrale: 488cm
# Spostamento totale accumulato rispetto alla poszione centrale: -176cm
# Spostamento totale accumulato rispetto alla poszione centrale: -632cm
# Spostamento totale accumulato rispetto alla poszione centrale: -124cm
# Spostamento totale accumulato rispetto alla poszione centrale: 242cm
# Spostamento totale accumulato rispetto alla poszione centrale: -734cm
# Spostamento totale accumulato rispetto alla poszione centrale: -1172cm
# Spostamento totale accumulato rispetto alla poszione centrale: 776cm
# Spostamento totale accumulato rispetto alla poszione centrale: -720cm
# Spostamento totale accumulato rispetto alla poszione centrale: -596cm
# Spostamento totale accumulato rispetto alla poszione centrale: -44cm
# Spostamento totale accumulato rispetto alla poszione centrale: 950cm
# Spostamento totale accumulato rispetto alla poszione centrale: -418cm
# Spostamento totale accumulato rispetto alla poszione centrale: -616cm
# Spostamento totale accumulato rispetto alla poszione centrale: 254cm
# Spostamento totale accumulato rispetto alla poszione centrale: 1730cm
# Spostamento totale accumulato rispetto alla poszione centrale: -348cm
# Spostamento totale accumulato rispetto alla poszione centrale: 554cm
# Spostamento totale accumulato rispetto alla poszione centrale: -232cm
# Spostamento totale accumulato rispetto alla poszione centrale: 1398cm
# Spostamento totale accumulato rispetto alla poszione centrale: -416cm
# Spostamento totale accumulato rispetto alla poszione centrale: 1078cm
# Spostamento totale accumulato rispetto alla poszione centrale: 530cm
# Spostamento totale accumulato rispetto alla poszione centrale: -56cm
# Spostamento totale accumulato rispetto alla poszione centrale: 668cm
# Spostamento totale accumulato rispetto alla poszione centrale: 204cm
# Spostamento totale accumulato rispetto alla poszione centrale: 366cm
# Spostamento totale accumulato rispetto alla poszione centrale: 782cm
# Spostamento totale accumulato rispetto alla poszione centrale: -96cm
# Spostamento totale accumulato rispetto alla poszione centrale: -552cm
# Spostamento totale accumulato rispetto alla poszione centrale: -650cm
# Spostamento totale accumulato rispetto alla poszione centrale: 672cm
# Spostamento totale accumulato rispetto alla poszione centrale: -246cm
# Spostamento totale accumulato rispetto alla poszione centrale: -1092cm
# Spostamento totale accumulato rispetto alla poszione centrale: 196cm
# Spostamento totale accumulato rispetto alla poszione centrale: 292cm
# Spostamento totale accumulato rispetto alla poszione centrale: 1052cm
# Spostamento totale accumulato rispetto alla poszione centrale: 524cm
# Spostamento totale accumulato rispetto alla poszione centrale: -522cm
# Spostamento totale accumulato rispetto alla poszione centrale: 394cm
# Spostamento totale accumulato rispetto alla poszione centrale: 312cm
# Spostamento totale accumulato rispetto alla poszione centrale: -426cm
# Spostamento totale accumulato rispetto alla poszione centrale: -562cm
# Spostamento totale accumulato rispetto alla poszione centrale: 1402cm
# Spostamento totale accumulato rispetto alla poszione centrale: 394cm
# Spostamento totale accumulato rispetto alla poszione centrale: -288cm
# Spostamento totale accumulato rispetto alla poszione centrale: -88cm
# Spostamento totale accumulato rispetto alla poszione centrale: 394cm
# Spostamento totale accumulato rispetto alla poszione centrale: -126cm
# Spostamento totale accumulato rispetto alla poszione centrale: 238cm
# Spostamento totale accumulato rispetto alla poszione centrale: -134cm
# Spostamento totale accumulato rispetto alla poszione centrale: 602cm
# Spostamento totale accumulato rispetto alla poszione centrale: -86cm
# Spostamento totale accumulato rispetto alla poszione centrale: -830cm
# Spostamento totale accumulato rispetto alla poszione centrale: 712cm
# Spostamento totale accumulato rispetto alla poszione centrale: -1624cm
# Spostamento totale accumulato rispetto alla poszione centrale: 1002cm
# Spostamento totale accumulato rispetto alla poszione centrale: 318cm
# Spostamento totale accumulato rispetto alla poszione centrale: -632cm
# Spostamento totale accumulato rispetto alla poszione centrale: 520cm
# Spostamento totale accumulato rispetto alla poszione centrale: 266cm
# Spostamento totale accumulato rispetto alla poszione centrale: 302cm
# Spostamento totale accumulato rispetto alla poszione centrale: -406cm
# Spostamento totale accumulato rispetto alla poszione centrale: 396cm
# Spostamento totale accumulato rispetto alla poszione centrale: 218cm
# Spostamento totale accumulato rispetto alla poszione centrale: 536cm
# Spostamento totale accumulato rispetto alla poszione centrale: -780cm
# Spostamento totale accumulato rispetto alla poszione centrale: 1072cm
# Spostamento totale accumulato rispetto alla poszione centrale: -846cm
# Spostamento totale accumulato rispetto alla poszione centrale: 74cm
# Spostamento totale accumulato rispetto alla poszione centrale: 132cm
# Spostamento totale accumulato rispetto alla poszione centrale: -456cm
# Spostamento totale accumulato rispetto alla poszione centrale: -796cm
# Spostamento totale accumulato rispetto alla poszione centrale: -108cm
# Spostamento totale accumulato rispetto alla poszione centrale: 594cm
# Spostamento totale accumulato rispetto alla poszione centrale: -532cm
# Spostamento totale accumulato rispetto alla poszione centrale: -554cm
# Spostamento totale accumulato rispetto alla poszione centrale: 198cm
# Spostamento totale accumulato rispetto alla poszione centrale: 1066cm
# Spostamento totale accumulato rispetto alla poszione centrale: 216cm
# Spostamento totale accumulato rispetto alla poszione centrale: 632cm
# Spostamento totale accumulato rispetto alla poszione centrale: 656cm
# Spostamento totale accumulato rispetto alla poszione centrale: 542cm
# Spostamento totale accumulato rispetto alla poszione centrale: -920cm
# Spostamento totale accumulato rispetto alla poszione centrale: 30cm
# Spostamento totale accumulato rispetto alla poszione centrale: -250cm
# Spostamento totale accumulato rispetto alla poszione centrale: 368cm
# Spostamento totale accumulato rispetto alla poszione centrale: -42cm
# Spostamento totale accumulato rispetto alla poszione centrale: 522cm
# Spostamento totale accumulato rispetto alla poszione centrale: -76cm
# Spostamento totale accumulato rispetto alla poszione centrale: -1096cm
# Spostamento totale accumulato rispetto alla poszione centrale: -1414cm
# Spostamento totale accumulato rispetto alla poszione centrale: 572cm
# Spostamento totale accumulato rispetto alla poszione centrale: -486cm
# Spostamento totale accumulato rispetto alla poszione centrale: 1262cm
# Spostamento totale accumulato rispetto alla poszione centrale: -316cm
# Spostamento totale accumulato rispetto alla poszione centrale: -86cm
# Spostamento totale accumulato rispetto alla poszione centrale: -328cm
# Spostamento totale accumulato rispetto alla poszione centrale: -776cm
# Spostamento totale accumulato rispetto alla poszione centrale: -500cm
# Spostamento totale accumulato rispetto alla poszione centrale: 1532cm
# Spostamento totale accumulato rispetto alla poszione centrale: 100cm
# Spostamento totale accumulato rispetto alla poszione centrale: -172cm
# Spostamento totale accumulato rispetto alla poszione centrale: 1064cm
# Spostamento totale accumulato rispetto alla poszione centrale: -166cm
# Spostamento totale accumulato rispetto alla poszione centrale: -40cm
# Spostamento totale accumulato rispetto alla poszione centrale: 458cm
# Spostamento totale accumulato rispetto alla poszione centrale: -326cm
# Spostamento totale accumulato rispetto alla poszione centrale: 16cm
# Spostamento totale accumulato rispetto alla poszione centrale: -506cm
# Spostamento totale accumulato rispetto alla poszione centrale: 74cm
# Spostamento totale accumulato rispetto alla poszione centrale: -994cm
# Spostamento totale accumulato rispetto alla poszione centrale: 540cm
# Spostamento totale accumulato rispetto alla poszione centrale: -892cm
# Spostamento totale accumulato rispetto alla poszione centrale: 1004cm
# Spostamento totale accumulato rispetto alla poszione centrale: 50cm
# Spostamento totale accumulato rispetto alla poszione centrale: -112cm
# Spostamento totale accumulato rispetto alla poszione centrale: 94cm
# Spostamento totale accumulato rispetto alla poszione centrale: -170cm
# Spostamento totale accumulato rispetto alla poszione centrale: -608cm
# Spostamento totale accumulato rispetto alla poszione centrale: 834cm
# Spostamento totale accumulato rispetto alla poszione centrale: -164cm
# Spostamento totale accumulato rispetto alla poszione centrale: -152cm
# Spostamento totale accumulato rispetto alla poszione centrale: -26cm
# Spostamento totale accumulato rispetto alla poszione centrale: 846cm
# Spostamento totale accumulato rispetto alla poszione centrale: -734cm
# Spostamento totale accumulato rispetto alla poszione centrale: -334cm
# Spostamento totale accumulato rispetto alla poszione centrale: 452cm
# Spostamento totale accumulato rispetto alla poszione centrale: -268cm
# Spostamento totale accumulato rispetto alla poszione centrale: 444cm
# Spostamento totale accumulato rispetto alla poszione centrale: 578cm
# Spostamento totale accumulato rispetto alla poszione centrale: -144cm
# Spostamento totale accumulato rispetto alla poszione centrale: -836cm
# 9.3 ms ± 498 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
