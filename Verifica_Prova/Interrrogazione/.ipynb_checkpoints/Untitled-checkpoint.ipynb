# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
file = open("netflix1.csv", encoding = "utf8")
righe = file.readlines()
file.close()

# %%
righe
# Out:
# ['Title,IMDb Score,Metacritic Score,Awards Received,Awards Nominated For,IMDb Votes\n',
#  'Lets Fight Ghost,7.9,82.0,74.0,57.0,205926.0\n',
#  'Joker,8.4,59.0,112.0,228.0,951938.0\n',
#  'I,6.5,51.0,26.0,69.0,733336.0\n',
#  'Harrys Daughters,8.1,85.0,46.0,94.0,766594.0\n',
#  'The Closet,7.0,72.0,1.0,1.0,16657.0\n',
#  'Dilili in Paris,7.0,37.0,1.0,2.0,816.0\n',
#  'Alice,6.6,67.0,1.0,7.0,13379.0\n',
#  'Ordinary People,7.7,86.0,19.0,14.0,47265.0\n',
#  'Paths of the Soul,7.5,90.0,5.0,7.0,738.0\n',
#  'The Return,8.0,82.0,34.0,19.0,42530.0\n',
#  'Stand by Me,8.1,75.0,5.0,11.0,364302.0\n',
#  'Wonderstruck,6.2,71.0,1.0,33.0,9533.0\n',
#  'The Girl on the Train,6.5,48.0,4.0,12.0,169614.0\n',
#  'Ride Your Wave,6.8,63.0,2.0,3.0,1601.0\n',
#  'A Call to Spy,6.3,65.0,3.0,2.0,1684.0\n',
#  'Red,7.0,60.0,4.0,19.0,290548.0\n',
#  'The Mole Agent,7.6,69.0,4.0,17.0,839.0\n',
#  'Burden,6.6,57.0,2.0,1.0,1814.0\n',
#  'Collective,8.4,95.0,25.0,42.0,3300.0\n',
#  'Love,6.1,51.0,2.0,1.0,48843.0\n',
#  'Amanda,7.0,63.0,4.0,7.0,2012.0\n',
#  'Corpus Christi,7.7,77.0,54.0,33.0,13208.0\n',
#  'John Lewis: Good Trouble,7.1,70.0,3.0,8.0,539.0\n',
#  'Repo Man,6.9,82.0,2.0,3.0,33965.0\n',
#  'Monsoon,5.9,69.0,1.0,2.0,1083.0\n',
#  'Weathering with You,7.5,72.0,6.0,16.0,23305.0\n',
#  'Monster Hunt 2,5.4,63.0,1.0,9.0,1399.0\n',
#  'Lassie Come Home,7.1,78.0,3.0,2.0,4973.0\n',
#  'News of the World,6.9,73.0,2.0,46.0,30581.0\n',
#  'Mr. & Mrs. Incredible,6.5,55.0,9.0,18.0,451482.0\n',
#  'Step,6.8,81.0,9.0,20.0,844.0\n',
#  'Breaking News,6.7,63.0,5.0,11.0,5087.0\n',
#  'The Great Race,7.3,71.0,3.0,14.0,16184.0\n',
#  'Ill Always Know What You Did Last Summer,6.5,51.0,26.0,69.0,733336.0\n',
#  'The House That Jack Built,6.8,42.0,11.0,20.0,59945.0\n',
#  'Trolls World Tour,6.1,51.0,1.0,8.0,16977.0\n',
#  'Sonic the Hedgehog,6.5,47.0,2.0,6.0,89305.0\n',
#  'Penguin Bloom,6.8,54.0,1.0,1.0,4163.0\n',
#  'Touch Me Not,5.9,65.0,4.0,19.0,2311.0\n',
#  'The Hunt,8.3,77.0,37.0,70.0,282998.0\n',
#  'Dragon,7.1,62.0,14.0,21.0,13870.0\n',
#  'Im Home,6.5,51.0,26.0,69.0,733336.0\n',
#  'Affliction,7.0,79.0,8.0,19.0,15218.0\n',
#  'Radium Girls,6.2,52.0,1.0,1.0,756.0\n',
#  'The Big Ugly,6.1,52.0,2.0,4.0,4024.0\n',
#  'Wish You,5.9,60.0,10.0,23.0,5228.0\n',
#  'Marlina the Murderer in Four Acts,7.0,77.0,19.0,26.0,2545.0\n',
#  'Sputnik,6.4,61.0,1.0,11.0,14642.0\n',
#  'Lupin,7.7,71.0,1.0,1.0,27154.0\n',
#  'You Cannot Kill David Arquette,7.2,66.0,1.0,2.0,1003.0\n',
#  'Infamous,7.0,68.0,3.0,2.0,16294.0\n',
#  'Pieces of a Woman,7.1,66.0,5.0,43.0,24585.0\n',
#  'Midnight Family,7.4,81.0,23.0,26.0,1412.0\n',
#  'My Girl,6.9,56.0,2.0,5.0,72575.0\n',
#  'Waves,7.6,80.0,14.0,39.0,18134.0\n',
#  'The Elephant Man,8.1,78.0,10.0,22.0,220688.0\n',
#  'Saint Frances,7.1,83.0,11.0,17.0,2423.0\n',
#  'Proxima,6.4,71.0,4.0,6.0,5296.0\n',
#  'Under the Silver Lake,6.5,60.0,3.0,9.0,33843.0\n',
#  'Butterfly,7.6,69.0,6.0,19.0,8277.0\n',
#  'High Life,5.8,77.0,5.0,15.0,29177.0\n',
#  'Evils Wave,7.8,61.0,9.0,10.0,35722.0\n',
#  'Like a Boss,4.6,33.0,1.0,5.0,10296.0\n',
#  'Just Mercy,7.6,68.0,10.0,15.0,47215.0\n',
#  'The Last Tree,6.5,67.0,3.0,11.0,796.0\n',
#  'Judy & Punch,6.8,66.0,23.0,61.0,41429.0\n',
#  'Grandmas Last Wishes,6.7,77.0,5.0,13.0,14680.0\n',
#  'The Midnight Sky,5.6,58.0,1.0,32.0,64680.0\n',
#  'House of Hummingbird,7.4,82.0,58.0,45.0,1745.0\n',
#  'Hotel by the River,6.7,79.0,6.0,12.0,1083.0\n',
#  'Vivarium,5.8,64.0,3.0,5.0,39277.0\n',
#  'Babyteeth,7.2,77.0,27.0,22.0,9757.0\n',
#  'The Invisible Man,7.1,72.0,19.0,39.0,167693.0\n',
#  'The Guys,6.3,60.0,1.0,2.0,1260.0\n',
#  'Farewell Amor,6.9,75.0,7.0,5.0,709.0\n',
#  'Grizzlies,7.5,69.0,7.0,9.0,1314.0\n',
#  'What If,6.8,59.0,2.0,8.0,71158.0\n',
#  'Living in Oblivion,7.5,81.0,7.0,8.0,16678.0\n',
#  'Louis & Luca - The Big Cheese Race,6.3,41.0,2.0,5.0,13515.0\n',
#  'Gilberts Grim Revenge,7.5,73.0,1.0,1.0,716.0\n',
#  'Deck the Halls,5.0,28.0,1.0,8.0,23597.0\n',
#  'I Can Only Imagine,7.3,30.0,6.0,4.0,14390.0\n',
#  'Mystery,7.0,51.0,3.0,8.0,221785.0\n',
#  'Me & You vs The World,8.1,75.0,16.0,46.0,837936.0\n',
#  'The Way Back,7.3,66.0,4.0,5.0,110733.0\n',
#  'The Whistleblower,7.1,59.0,8.0,11.0,31769.0\n',
#  'Canvas,6.6,67.0,9.0,1.0,981.0\n',
#  'Its Me. Its Me,7.3,69.0,8.0,47.0,460854.0\n',
#  'Winter Flies,6.4,79.0,7.0,13.0,371.0\n',
#  'Friday,7.3,54.0,1.0,5.0,100390.0\n',
#  'Babel,7.4,69.0,43.0,136.0,289958.0\n',
#  'The War of the Worlds,7.1,78.0,5.0,2.0,32807.0\n',
#  'Halloween 4: The Return of Michael Myers,5.9,34.0,1.0,2.0,44178.0\n',
#  'Emma,6.6,66.0,3.0,7.0,36103.0\n',
#  'Abominable,7.0,61.0,4.0,22.0,29620.0\n',
#  'MANK,7.1,79.0,27.0,167.0,38316.0\n',
#  'The Whistlers,6.3,76.0,11.0,16.0,4219.0\n',
#  'RELIC,6.0,77.0,4.0,16.0,16116.0\n',
#  'The Truth,6.5,75.0,1.0,2.0,4868.0\n',
#  'Dora and the Lost City of Gold,6.1,63.0,4.0,2.0,24321.0\n',
#  'Blue Story,6.0,69.0,1.0,13.0,3417.0\n',
#  'The Rhythm Section,5.3,45.0,1.0,3.0,12701.0\n',
#  'Godzilla & Mothra: Battle for Earth,6.4,62.0,7.0,31.0,377876.0\n',
#  'Godzilla,6.4,62.0,7.0,31.0,377876.0\n',
#  'Fiction.,8.9,94.0,70.0,75.0,1831004.0\n',
#  'The Guest,6.7,76.0,4.0,13.0,91927.0\n',
#  'Respiro,7.0,65.0,21.0,11.0,4517.0\n',
#  'The Embalmer,7.0,71.0,16.0,20.0,2312.0\n',
#  'A Perfect Day,6.8,60.0,4.0,21.0,20595.0\n',
#  'The Sisters Brothers,7.0,78.0,11.0,23.0,54525.0\n',
#  'The Man Who Killed Don Quixote,6.4,58.0,4.0,7.0,16212.0\n',
#  'Deliver Us,6.4,63.0,2.0,2.0,264.0\n',
#  'True History of the Kelly Gang,6.0,75.0,6.0,13.0,7968.0\n',
#  'Widows,6.9,84.0,18.0,94.0,87559.0\n',
#  'The Wretched,5.8,61.0,4.0,4.0,10850.0\n',
#  'Im Standing on a Million Lives,6.5,51.0,26.0,69.0,733336.0\n',
#  'Motherless Brooklyn,6.8,60.0,2.0,15.0,44513.0\n',
#  'Richard Jewell,7.5,68.0,7.0,19.0,63671.0\n',
#  'Birds of Prey (And the Fantabulous Emancipation of One Harley Quinn),6.1,60.0,5.0,38.0,168176.0\n',
#  'American Animals,7.0,68.0,10.0,21.0,38839.0\n',
#  'The Call,6.7,51.0,1.0,11.0,113200.0\n',
#  'Hillbilly Elegy,6.8,38.0,1.0,15.0,23416.0\n',
#  'Whose Streets?,5.4,79.0,2.0,18.0,1230.0\n',
#  'Playing with Fire,5.1,24.0,2.0,2.0,11019.0\n',
#  'Rocketman,7.3,69.0,21.0,70.0,138522.0\n',
#  'Gemini Man,5.7,38.0,1.0,5.0,86715.0\n',
#  'A Guy & A Girl,6.4,45.0,1.0,8.0,212311.0\n',
#  'The Life Ahead,6.8,66.0,8.0,24.0,7696.0\n',
#  'The Liberator,6.8,51.0,1.0,3.0,5038.0\n',
#  'Axolotl Overkill,5.3,65.0,2.0,5.0,704.0\n',
#  'The Hero,6.5,61.0,2.0,6.0,8137.0\n',
#  'Girls Revenge,8.1,79.0,64.0,187.0,863582.0\n',
#  'Paranormal,6.3,68.0,3.0,12.0,220740.0\n',
#  'The War of the Roses,6.9,79.0,2.0,9.0,48270.0\n',
#  'Harriet,6.6,66.0,23.0,50.0,19939.0\n',
#  'Dolittle,5.6,26.0,1.0,1.0,48589.0\n',
#  'Cats,2.8,32.0,11.0,7.0,42619.0\n',
#  'Love & Anarchy,6.1,51.0,2.0,1.0,48843.0\n',
#  'The Mermaid,6.2,69.0,8.0,13.0,8284.0\n',
#  'MOTHER,7.8,79.0,44.0,46.0,53293.0\n',
#  'Evil,7.8,61.0,9.0,10.0,35722.0\n',
#  'The Outpost,6.8,71.0,1.0,5.0,20459.0\n',
#  'Raising Victor Vargas,7.2,83.0,4.0,14.0,5244.0\n',
#  'Tortilla Soup,6.7,58.0,2.0,7.0,4423.0\n',
#  'Yes. God. Yes,6.1,71.0,2.0,1.0,9632.0\n',
#  'I Am Woman,6.6,54.0,1.0,11.0,1585.0\n',
#  'The Hummingbird Project,6.2,58.0,2.0,5.0,12037.0\n',
#  'Amandla! A Revolution in Four Part Harmony,7.4,78.0,11.0,7.0,562.0\n',
#  'Sleeper,7.2,77.0,2.0,2.0,39767.0\n',
#  'The Mountain Between Us,6.4,48.0,2.0,1.0,67847.0\n',
#  'Im Not Ready for Christmas,6.5,51.0,26.0,69.0,733336.0\n',
#  'Habermann,7.1,46.0,5.0,7.0,1019.0\n',
#  '1917,8.3,78.0,123.0,180.0,430438.0\n',
#  'His House,6.5,72.0,4.0,20.0,23939.0\n',
#  'The Queens Gambit,7.3,91.0,96.0,97.0,104495.0\n',
#  'Im losing it,6.5,51.0,26.0,69.0,733336.0\n',
#  'Rebecca,8.1,86.0,7.0,10.0,124423.0\n',
#  'Bending the Arc,7.7,80.0,1.0,1.0,188.0\n',
#  'Disappearance at Clifton Hill,5.5,61.0,1.0,9.0,1848.0\n',
#  'The Trial of the Chicago 7,7.8,77.0,31.0,119.0,94389.0\n',
#  'The Forty-Year-Old Version,7.2,80.0,13.0,24.0,3253.0\n',
#  'Honey Boy,7.3,73.0,10.0,37.0,28105.0\n',
#  'Black Christmas,7.2,65.0,2.0,2.0,34569.0\n',
#  'David Attenborough: A Life on Our Planet,9.0,72.0,3.0,2.0,24796.0\n',
#  'Spotlight,8.1,93.0,124.0,143.0,422721.0\n',
#  'Judy,6.8,66.0,23.0,61.0,41429.0\n',
#  'Dick Johnson Is Dead,7.5,89.0,17.0,28.0,4163.0\n',
#  'Aliens,8.3,84.0,20.0,23.0,654147.0\n',
#  'Im Leaving Now,6.5,51.0,26.0,69.0,733336.0\n',
#  'Time Out,7.4,88.0,2.0,8.0,4645.0\n',
#  'My Mothers Wound,6.8,70.0,12.0,26.0,6950.0\n',
#  'Rhino Season,6.4,66.0,6.0,6.0,6239.0\n',
#  'Rojo,6.4,76.0,15.0,26.0,1896.0\n',
#  'One Day,7.0,48.0,1.0,2.0,139731.0\n',
#  'High & Low The Worst,7.6,88.0,47.0,167.0,205077.0\n',
#  'High & Low The Movie 3 / Final Mission,7.6,88.0,47.0,167.0,205077.0\n',
#  'High & Low The Movie 2 / End of Sky,7.6,88.0,47.0,167.0,205077.0\n',
#  'High & Low The Red Rain,7.6,88.0,47.0,167.0,205077.0\n',
#  'High & Low The Movie,7.6,88.0,47.0,167.0,205077.0\n',
#  'Dragons Dogma,7.1,62.0,14.0,21.0,13870.0\n',
#  'Battle of the Sexes,6.7,73.0,3.0,22.0,50309.0\n',
#  'Patti Cake$,6.8,67.0,9.0,15.0,9579.0\n',
#  'The Lighthouse,7.5,83.0,32.0,131.0,146042.0\n',
#  'Wild Rose,7.2,80.0,17.0,34.0,10863.0\n',
#  'The Duchess,6.9,62.0,8.0,21.0,78504.0\n',
#  'The Teacher,7.3,77.0,8.0,14.0,3076.0\n',
#  'Whos Afraid of the Wolf,6.6,59.0,18.0,31.0,217014.0\n',
#  'Cuties,3.1,67.0,1.0,5.0,26761.0\n',
#  'The Social Dilemma,7.7,78.0,3.0,11.0,64767.0\n',
#  'Cargo,6.3,65.0,1.0,17.0,37588.0\n',
#  'Lingua Franca,6.3,61.0,6.0,19.0,422.0\n',
#  'Quantum of Solace,6.6,58.0,4.0,32.0,406102.0\n',
#  'We Summon the Darkness,5.2,55.0,1.0,1.0,7540.0\n',
#  'Children of the Sea,6.5,74.0,2.0,1.0,1692.0\n',
#  '1BR,5.8,56.0,2.0,2.0,8938.0\n',
#  'Afterschool,6.1,66.0,1.0,10.0,4377.0\n',
#  'Matt & Mou,7.6,75.0,8.0,2.0,1479.0\n',
#  'Somewhere In Time,7.2,29.0,7.0,4.0,26950.0\n',
#  'Still Life,7.4,45.0,19.0,5.0,7414.0\n',
#  'The Tree,6.6,58.0,1.0,16.0,4377.0\n',
#  'Outbreak,6.6,64.0,5.0,5.0,120516.0\n',
#  'A Beautiful Day in the Neighborhood,7.3,80.0,6.0,63.0,61847.0\n',
#  'Anastasia,7.2,61.0,10.0,23.0,112420.0\n',
#  'Im Thinking of Ending Things,6.5,51.0,26.0,69.0,733336.0\n',
#  'Parasite,8.6,96.0,300.0,262.0,566337.0\n',
#  'The Invisibles,7.1,60.0,1.0,3.0,1147.0\n',
#  'Whos Next?,6.6,59.0,18.0,31.0,217014.0\n',
#  'The Platform,7.0,73.0,12.0,24.0,165577.0\n',
#  'Chefs Table: BBQ,7.3,68.0,2.0,4.0,197249.0\n',
#  'Hustlers,6.3,79.0,22.0,71.0,84147.0\n',
#  'Bullitt,7.4,81.0,7.0,9.0,61088.0\n',
#  'The New World,6.7,69.0,6.0,34.0,83031.0\n',
#  'By the Grace of God,7.2,75.0,4.0,19.0,5423.0\n',
#  'Official Secrets,7.3,63.0,5.0,15.0,34686.0\n',
#  'Bloodshot,5.7,44.0,1.0,4.0,61517.0\n',
#  'Neighbors,6.3,68.0,8.0,11.0,287502.0\n',
#  'Vice,7.2,61.0,35.0,133.0,122744.0\n',
#  'Greta,6.0,54.0,1.0,4.0,25644.0\n',
#  'Fearless,7.6,70.0,6.0,13.0,72960.0\n',
#  'My Friend A,6.2,68.0,1.0,3.0,16532.0\n',
#  'Joker,8.4,59.0,112.0,228.0,951938.0\n',
#  'Doctor Sleep,7.3,59.0,7.0,29.0,144369.0\n',
#  'Worlds Most Wanted,7.0,63.0,3.0,24.0,602843.0\n',
#  'Sin City,8.0,74.0,38.0,54.0,739118.0\n',
#  'The Peanut Butter Falcon,7.6,70.0,21.0,16.0,67536.0\n',
#  'Almost Love,5.6,42.0,7.0,1.0,772.0\n',
#  'Knives Out,7.9,82.0,43.0,98.0,459839.0\n',
#  'Be with Me,7.0,67.0,12.0,7.0,1631.0\n',
#  'The Nightingale,7.3,77.0,25.0,34.0,21684.0\n',
#  'Instinct,6.6,43.0,1.0,2.0,31884.0\n',
#  'The Grudge,5.9,49.0,2.0,10.0,138933.0\n',
#  'Bad Boys for Life,6.6,59.0,2.0,12.0,131495.0\n',
#  'Barb Wire,3.3,40.0,1.0,7.0,25195.0\n',
#  'Oh Lucy!,6.8,69.0,3.0,9.0,2805.0\n',
#  'The Call,6.7,51.0,1.0,11.0,113200.0\n',
#  'Father,7.2,30.0,17.0,14.0,11323.0\n',
#  'Surfers Time,5.6,45.0,3.0,17.0,250957.0\n',
#  'Stars,7.7,69.0,21.0,15.0,345122.0\n',
#  'Its Her Day,7.3,69.0,8.0,47.0,460854.0\n',
#  'Meet the Parents,7.0,73.0,7.0,15.0,311557.0\n',
#  'Banana Split,6.2,63.0,3.0,4.0,2384.0\n',
#  'Forsaken,6.3,55.0,1.0,9.0,10537.0\n',
#  'The Kissing Booth 2,5.8,39.0,1.0,1.0,20131.0\n',
#  'Ip Man 4: The Finale,7.0,62.0,12.0,10.0,24753.0\n',
#  'Asako I & II,6.9,68.0,6.0,11.0,2021.0\n',
#  'Never Look Away,7.7,68.0,5.0,20.0,16620.0\n',
#  'Funan,6.9,79.0,3.0,2.0,766.0\n',
#  'Father Soldier Son,7.4,74.0,1.0,1.0,773.0\n',
#  'The Invisibles,7.1,60.0,1.0,3.0,1147.0\n',
#  'Bombshell,6.8,64.0,22.0,58.0,91427.0\n',
#  'A Dogs Journey,7.5,82.0,15.0,5.0,18412.0\n',
#  'Western Stars,7.5,80.0,1.0,2.0,1513.0\n',
#  'The Beach Bum,5.5,55.0,1.0,7.0,18564.0\n',
#  'Id like to Borrow a Girlfriend,6.5,51.0,26.0,69.0,733336.0\n',
#  'Color Out of Space,6.2,70.0,5.0,10.0,33992.0\n',
#  'About Time,7.8,55.0,3.0,9.0,304576.0\n',
#  'Heartbeats,7.1,70.0,6.0,15.0,27508.0\n',
#  'Grace,5.1,52.0,2.0,5.0,7682.0\n',
#  'I See You,6.8,65.0,1.0,1.0,30638.0\n',
#  'The Hater,7.1,61.0,1.0,1.0,10803.0\n',
#  'The Old Guard,6.6,70.0,2.0,16.0,128402.0\n',
#  'The Maid,7.3,82.0,34.0,23.0,5675.0\n',
#  'Little Women,7.8,91.0,74.0,205.0,145961.0\n',
#  'Mamas Boy,6.2,57.0,11.0,19.0,169029.0\n',
#  'Mucho Mucho Amor: The Legend of Walter Mercado,7.3,76.0,2.0,5.0,2750.0\n',
#  'Prince of Darkness,6.7,50.0,1.0,1.0,37755.0\n',
#  'Loving,7.0,79.0,25.0,86.0,32033.0\n',
#  'Hook,6.8,52.0,7.0,22.0,235730.0\n',
#  'Sisters in Law,7.2,71.0,6.0,3.0,377.0\n',
#  'Shaft,5.9,50.0,1.0,13.0,73632.0\n',
#  'Rio,6.9,63.0,3.0,31.0,206870.0\n',
#  'The Silence of Others,8.0,73.0,30.0,13.0,1673.0\n',
#  'My Cousin Rachel,6.0,63.0,1.0,4.0,17819.0\n',
#  'Mug,6.4,70.0,4.0,6.0,2209.0\n',
#  'Chavela,7.8,68.0,6.0,5.0,908.0\n',
#  'Skin,6.9,58.0,1.0,3.0,12388.0\n',
#  'Assassination Nation,5.9,56.0,1.0,4.0,15772.0\n',
#  'Eurovision Song Contest: The Story of Fire Saga,6.5,50.0,1.0,12.0,73403.0\n',
#  'Ordinary People,7.7,86.0,19.0,14.0,47265.0\n',
#  'Athlete A,7.7,85.0,3.0,6.0,7350.0\n',
#  'Red,7.0,60.0,4.0,19.0,290548.0\n',
#  'Human Capital,7.3,63.0,48.0,30.0,11796.0\n',
#  'Its Okay to Not Be Okay,7.3,69.0,8.0,47.0,460854.0\n',
#  'Truman,7.3,81.0,30.0,32.0,11933.0\n',
#  'Jumanji: The Next Level,6.6,58.0,1.0,8.0,189051.0\n',
#  'Wasp Network,5.9,54.0,1.0,3.0,8167.0\n',
#  'Disclosure,6.1,58.0,2.0,2.0,46614.0\n',
#  'Yesterday,6.8,55.0,1.0,15.0,115232.0\n',
#  'The King,7.2,62.0,12.0,28.0,90599.0\n',
#  'Scary Stories to Tell in the Dark,6.2,61.0,4.0,5.0,61293.0\n',
#  'The Land,6.4,50.0,2.0,3.0,1607.0\n',
#  'Ghosts of Cité Soleil,7.1,64.0,2.0,4.0,1731.0\n',
#  'Les Misérables,7.6,63.0,86.0,175.0,309494.0\n',
#  '22 минуты,7.0,71.0,7.0,24.0,346712.0\n',
#  'The Pirogue,6.7,74.0,2.0,2.0,383.0\n',
#  '2 дня,8.5,75.0,36.0,33.0,996880.0\n',
#  'CALM WITH HORSES,6.9,67.0,1.0,17.0,3146.0\n',
#  'Викинг 18+,5.2,24.0,1.0,2.0,53947.0\n',
#  'Честное пионерское 2,8.5,75.0,36.0,33.0,996880.0\n',
#  'Честное пионерское 3,8.2,92.0,61.0,95.0,758769.0\n',
#  '8 первых свиданий,7.0,72.0,11.0,70.0,338803.0\n',
#  'The White Crow,6.6,61.0,1.0,3.0,5246.0\n',
#  'Ma,5.6,53.0,1.0,5.0,40452.0\n',
#  'The Last Black Man in San Francisco,7.3,83.0,17.0,51.0,14687.0\n',
#  'Fast & Furious Presents: Hobbs & Shaw,7.0,61.0,10.0,22.0,368985.0\n',
#  'Good Boys,6.7,60.0,2.0,7.0,60624.0\n',
#  'The Other Lamb,5.2,65.0,2.0,3.0,3268.0\n',
#  'Da 5 Bloods,6.5,82.0,28.0,108.0,39293.0\n',
#  'Cats,2.8,32.0,11.0,7.0,42619.0\n',
#  'Angel Heart,7.3,61.0,2.0,4.0,80843.0\n',
#  'The Third Murder,6.7,68.0,6.0,18.0,5514.0\n',
#  'VFW,6.1,72.0,2.0,1.0,5840.0\n',
#  'Lean on Pete,7.2,80.0,11.0,16.0,11430.0\n',
#  'It Chapter Two,6.5,58.0,5.0,25.0,208462.0\n',
#  'Spelling the Dream,6.9,64.0,1.0,1.0,619.0\n',
#  'The Addams Family,6.9,57.0,5.0,21.0,137664.0\n',
#  'Mirai,7.0,81.0,5.0,34.0,12653.0\n',
#  'Maiden,7.7,82.0,8.0,11.0,1786.0\n',
#  'The Song of Names,6.4,51.0,6.0,7.0,2582.0\n',
#  'Untouchable,6.7,71.0,1.0,6.0,2153.0\n',
#  'Night,6.4,48.0,2.0,8.0,315066.0\n',
#  'Im No Longer Here,6.5,51.0,26.0,69.0,733336.0\n',
#  'Ne Zha,7.5,54.0,20.0,23.0,5843.0\n',
#  'Snowpiercer,7.1,84.0,34.0,105.0,322589.0\n',
#  'Monos,6.9,78.0,29.0,64.0,14433.0\n',
#  'Mystify: Michael Hutchence,7.3,73.0,1.0,7.0,1927.0\n',
#  'Whats Up?,6.4,47.0,5.0,9.0,191853.0\n',
#  'Lets Dance,7.9,82.0,74.0,57.0,205926.0\n',
#  'For Sama,8.5,89.0,69.0,45.0,9084.0\n',
#  'Human Nature,6.4,56.0,2.0,2.0,17500.0\n',
#  'Colette,6.7,74.0,1.0,9.0,19625.0\n',
#  'Ali & Alia,6.8,65.0,10.0,27.0,93996.0\n',
#  'Ophelia,6.6,60.0,4.0,4.0,7790.0\n',
#  'Skin,6.9,58.0,1.0,3.0,12388.0\n',
#  'The Circus,8.1,90.0,1.0,3.0,30357.0\n',
#  'Black Cat. White Cat,8.1,73.0,5.0,5.0,51036.0\n',
#  'The Half Of It,6.9,74.0,2.0,7.0,28540.0\n',
#  'Step,6.8,81.0,9.0,20.0,844.0\n',
#  'Gangsters Paradise: Jerusalema,7.3,53.0,6.0,1.0,10348.0\n',
#  'Dangerous Lies,5.3,51.0,1.0,1.0,14133.0\n',
#  'Summertime,7.0,69.0,1.0,4.0,85.0\n',
#  'Extraction,6.7,56.0,1.0,7.0,160810.0\n',
#  'The Soft Skin,7.5,78.0,1.0,1.0,6910.0\n',
#  'Black and Blue,6.4,54.0,1.0,2.0,16759.0\n',
#  'Circus of Books,7.0,74.0,2.0,3.0,3600.0\n',
#  'What They Had,6.6,69.0,3.0,4.0,3534.0\n',
#  'Sergio,6.1,55.0,1.0,1.0,8217.0\n',
#  'Rambo: Last Blood,6.1,26.0,4.0,8.0,83109.0\n',
#  'Little,5.5,49.0,3.0,6.0,11000.0\n',
#  'Gemini,5.4,71.0,1.0,5.0,4557.0\n',
#  'Wolf,7.3,52.0,7.0,13.0,3532.0\n',
#  'What to Do in Case of Fire,6.8,47.0,2.0,3.0,3546.0\n',
#  'Sing Yesterday for Me,7.1,59.0,3.0,25.0,134434.0\n',
#  'The Front Runner,6.1,61.0,1.0,4.0,11531.0\n',
#  'Fame,6.6,58.0,7.0,16.0,20420.0\n',
#  'All Is True,6.2,59.0,1.0,3.0,3513.0\n',
#  'When Marnie Was There,7.7,72.0,4.0,18.0,33263.0\n',
#  'Pom Poko,7.3,77.0,3.0,1.0,25489.0\n',
#  'Howl’s Moving Castle,8.2,80.0,14.0,20.0,335164.0\n',
#  'From Up on Poppy Hill,7.4,71.0,6.0,11.0,36118.0\n',
#  'Anatomy,6.1,33.0,1.0,3.0,11721.0\n',
#  'The Insult,7.7,72.0,18.0,15.0,14890.0\n',
#  'Bethany Hamilton: Unstoppable,7.4,55.0,3.0,1.0,556.0\n',
#  'Brimstone,7.1,45.0,11.0,12.0,36815.0\n',
#  'The Platform,7.0,73.0,12.0,24.0,165577.0\n',
#  'Overcomer,6.7,17.0,2.0,2.0,3748.0\n',
#  'Extra Ordinary,6.4,72.0,15.0,7.0,7767.0\n',
#  'The Mustang,6.9,77.0,6.0,9.0,9954.0\n',
#  'Them That Follow,5.3,57.0,1.0,5.0,2782.0\n',
#  'Maquia: When the Promised Flower Blooms,7.5,72.0,1.0,1.0,4392.0\n',
#  'Once Upon a Time in Hollywood,7.6,83.0,139.0,355.0,554416.0\n',
#  'Q Ball,6.8,69.0,1.0,2.0,545.0\n',
#  'Miles Davis: Birth of the Cool,7.4,76.0,1.0,7.0,1463.0\n',
#  'Stuff and Dough,7.2,76.0,6.0,4.0,1867.0\n',
#  'Freaks,6.7,63.0,9.0,13.0,27292.0\n',
#  'Sieranevada,7.3,82.0,21.0,19.0,4725.0\n',
#  'The Death of Mr. Lazarescu,7.9,86.0,30.0,14.0,13814.0\n',
#  'Aurora,6.6,63.0,7.0,8.0,1728.0\n',
#  'White Wedding,5.8,60.0,1.0,7.0,577.0\n',
#  'October Sky,7.8,71.0,4.0,11.0,83109.0\n',
#  'Apollo 11,8.2,88.0,55.0,42.0,22107.0\n',
#  'Hotel Mumbai,7.6,62.0,9.0,25.0,53664.0\n',
#  'Lady Macbeth,6.8,76.0,21.0,51.0,19877.0\n',
#  'Nausicaä of the Valley of the Wind,8.1,86.0,3.0,1.0,151542.0\n',
#  'Paradise Hills,5.5,49.0,1.0,21.0,10942.0\n',
#  'Unstoppable,6.8,69.0,1.0,14.0,184884.0\n',
#  'Godzilla: King of the Monsters,6.0,48.0,6.0,13.0,138412.0\n',
#  'The Angry Birds Movie 2,6.4,60.0,1.0,3.0,21495.0\n',
#  'Girl on the Third Floor,4.6,65.0,2.0,2.0,7778.0\n',
#  'System Crasher,7.8,90.0,31.0,24.0,9406.0\n',
#  'Ana. Mon Amour,6.8,63.0,1.0,7.0,1810.0\n',
#  'A Shaun the Sheep Movie: Farmageddon,6.9,79.0,2.0,9.0,9050.0\n',
#  'Puzzle,6.7,66.0,2.0,2.0,6828.0\n',
#  'The Ballad of Lefty Brown,6.3,64.0,1.0,1.0,5510.0\n',
#  'Late Night,6.5,70.0,1.0,9.0,29050.0\n',
#  'Grandmas Wedding,6.7,77.0,5.0,13.0,14680.0\n',
#  'Red Sparrow,6.6,53.0,3.0,8.0,166815.0\n',
#  'Only Yesterday,7.6,90.0,1.0,8.0,27317.0\n',
#  'Uncut Gems,7.4,91.0,22.0,81.0,223217.0\n',
#  '37 Seconds,7.3,62.0,8.0,3.0,2060.0\n',
#  'Miss Americana,7.4,65.0,2.0,4.0,15836.0\n',
#  'The Children Act,6.7,62.0,2.0,4.0,11310.0\n',
#  'Mandy,6.5,81.0,12.0,41.0,64711.0\n',
#  'Childs Play,5.8,48.0,2.0,6.0,44455.0\n',
#  'Whisky,7.0,66.0,23.0,7.0,5702.0\n',
#  'Toni Morrison: The Pieces I Am,7.4,82.0,8.0,9.0,523.0\n',
#  'The Biggest Little Farm,8.1,73.0,15.0,28.0,5572.0\n',
#  'Autumn Spring,7.5,68.0,9.0,6.0,1721.0\n',
#  'The Curse of La Llorona,5.3,41.0,1.0,7.0,38454.0\n',
#  'Jezebel,5.7,80.0,3.0,3.0,350.0\n',
#  '1945,7.1,73.0,7.0,5.0,3332.0\n',
#  'The Prodigy,5.9,45.0,1.0,1.0,23254.0\n',
#  'Long shot,6.8,67.0,5.0,11.0,94892.0\n',
#  'Missing Link,6.7,68.0,5.0,44.0,22105.0\n',
#  'Spider-Man: Far from Home,7.5,69.0,10.0,22.0,325685.0\n',
#  'The Hustle,5.4,35.0,3.0,3.0,47958.0\n',
#  'True Romance,7.9,59.0,1.0,10.0,207489.0\n',
#  'The Circle,5.3,43.0,3.0,1.0,85020.0\n',
#  'My Own Private Idaho,7.1,77.0,12.0,10.0,51205.0\n',
#  'Ghost Stories,6.4,68.0,1.0,7.0,31460.0\n',
#  'John Wick: Chapter 3 - Parabellum,7.4,73.0,16.0,26.0,278016.0\n',
#  'Ask Dr. Ruth,7.6,68.0,3.0,5.0,869.0\n',
#  'Us,6.8,81.0,77.0,116.0,228427.0\n',
#  'Whos the Woman. Whos the Man,6.6,59.0,18.0,31.0,217014.0\n',
#  'Thunder Road,7.1,79.0,14.0,14.0,14932.0\n',
#  'Fighting with My Family,7.1,68.0,11.0,4.0,66920.0\n',
#  'First Reformed,7.1,85.0,61.0,103.0,48131.0\n',
#  'Pet Sematary,5.7,57.0,1.0,9.0,81966.0\n',
#  'The Two Popes,7.6,75.0,12.0,57.0,107567.0\n',
#  'Whats New Scooby-Doo?,6.4,47.0,5.0,9.0,191853.0\n',
#  'One Floor Below,6.4,66.0,7.0,11.0,830.0\n',
#  '6 Underground,6.1,41.0,1.0,9.0,140378.0\n',
#  'Divided We Fall,7.6,69.0,15.0,4.0,4872.0\n',
#  'Mary. Queen of Scots,6.3,60.0,7.0,32.0,41911.0\n',
#  'Midsommar,7.1,72.0,26.0,66.0,202246.0\n',
#  'Incident in a Ghostland,6.4,44.0,6.0,5.0,24984.0\n',
#  'Infinite Football,6.6,75.0,1.0,3.0,400.0\n',
#  '12:08 East of Bucharest,7.4,77.0,12.0,13.0,7171.0\n',
#  'Hail Satan?,7.3,76.0,3.0,19.0,5650.0\n',
#  'On the Basis of Sex,7.1,59.0,3.0,12.0,28211.0\n',
#  'Marriage Story,7.9,94.0,127.0,265.0,250211.0\n',
#  'The Shape of Water,7.3,87.0,137.0,345.0,372534.0\n',
#  'The Greatest Showman,7.6,48.0,18.0,35.0,241486.0\n',
#  'The House with a Clock in Its Walls,6.1,57.0,1.0,1.0,45818.0\n',
#  'The Hole in the Ground,5.6,63.0,2.0,17.0,15874.0\n',
#  'A Private War,6.7,75.0,1.0,9.0,16711.0\n',
#  'I Lost My Body,7.6,81.0,31.0,51.0,26940.0\n',
#  'Atlantics,6.7,85.0,14.0,58.0,7962.0\n',
#  'Gods Little Village,8.6,79.0,75.0,49.0,700405.0\n',
#  'The Island,6.3,61.0,7.0,13.0,1379.0\n',
#  'The LEGO Movie 2: The Second Part,6.6,65.0,1.0,12.0,55397.0\n',
#  'Ruben Brandt. Collector,7.5,75.0,2.0,6.0,6386.0\n',
#  'The Body Remembers When the World Broke Open,6.9,87.0,13.0,12.0,578.0\n',
#  'The Irishman,7.9,94.0,74.0,334.0,328049.0\n',
#  'Welcome to Marwen,6.2,40.0,2.0,8.0,20193.0\n',
#  'How to Train Your Dragon: The Hidden World,7.5,71.0,5.0,61.0,105076.0\n',
#  'Marie Curie: The Courage of Knowledge,5.5,49.0,3.0,8.0,1211.0\n',
#  'Brightburn,6.1,44.0,1.0,2.0,79451.0\n',
#  'The Longest Yard,7.1,61.0,2.0,4.0,17201.0\n',
#  'Diego Maradona,7.7,78.0,1.0,13.0,13955.0\n',
#  'The Club,7.2,73.0,19.0,29.0,9753.0\n',
#  'Im with the Band: Nasty Cherry,6.5,51.0,26.0,69.0,733336.0\n',
#  'Klaus,8.2,65.0,10.0,25.0,106820.0\n',
#  'Loners,7.5,33.0,10.0,12.0,2843.0\n',
#  'A Bride for Rip Van Winkle,7.2,56.0,2.0,6.0,1388.0\n',
#  'Papi Chulo,6.5,42.0,1.0,3.0,1258.0\n',
#  'Beauty in Trouble,6.8,75.0,6.0,6.0,894.0\n',
#  'Fifty Shades Freed,4.5,31.0,6.0,10.0,56092.0\n',
#  'Boy Erased,6.9,69.0,11.0,49.0,32734.0\n',
#  'Up and Down,6.9,78.0,6.0,10.0,1871.0\n',
#  'Birds of Passage,7.5,85.0,31.0,39.0,10231.0\n',
#  'Shadow,7.0,81.0,37.0,58.0,12875.0\n',
#  'Burning Cane,5.5,74.0,4.0,17.0,546.0\n',
#  'Thoroughbreds,6.7,75.0,1.0,21.0,35682.0\n',
#  'Murder on The Orient Express,6.5,52.0,1.0,25.0,213437.0\n',
#  'The Public,6.6,46.0,5.0,1.0,3387.0\n',
#  'Three Billboards Outside Ebbing. Missouri,8.1,88.0,132.0,225.0,436020.0\n',
#  'Ferdinand,6.7,58.0,2.0,20.0,48883.0\n',
#  'The King,7.2,62.0,12.0,28.0,90599.0\n',
#  'You Were Never Really Here,6.8,84.0,24.0,71.0,105181.0\n',
#  'Dolemite Is My Name,7.3,76.0,29.0,65.0,53517.0\n',
#  'Echo in the Canyon,6.9,69.0,2.0,3.0,2489.0\n',
#  'Hellboy,5.2,31.0,1.0,8.0,78429.0\n',
#  'The Mule,7.0,58.0,1.0,10.0,113799.0\n',
#  'Breaking News,6.7,63.0,5.0,11.0,5087.0\n',
#  'Dogman,7.2,71.0,39.0,31.0,22596.0\n',
#  'El Camino: A Breaking Bad Movie,7.3,72.0,4.0,22.0,185086.0\n',
#  'They Shall Not Grow Old,8.3,91.0,5.0,11.0,29612.0\n',
#  'Dark Blue World,7.2,56.0,8.0,7.0,5533.0\n',
#  'Ransom,6.7,60.0,3.0,5.0,119153.0\n',
#  'Mortal Engines,6.1,44.0,3.0,3.0,110107.0\n',
#  'One Cut of the Dead,7.7,86.0,26.0,21.0,17827.0\n',
#  'In the Tall Grass,5.4,46.0,2.0,3.0,46996.0\n',
#  'Clara,6.7,43.0,2.0,4.0,3818.0\n',
#  'Five Feet Apart,7.2,53.0,3.0,7.0,44352.0\n',
#  'Dark City,7.6,66.0,12.0,19.0,188244.0\n',
#  'The Last Family,7.5,69.0,30.0,16.0,3612.0\n',
#  'Green Book,8.2,69.0,58.0,119.0,382033.0\n',
#  'Phantom Thread,7.5,90.0,55.0,119.0,112946.0\n',
#  'Between Two Ferns: The Movie,6.1,59.0,1.0,2.0,26807.0\n',
#  'If Beale Street Could Talk,7.1,87.0,107.0,176.0,42426.0\n',
#  'The Battleship Island,7.1,60.0,8.0,11.0,5844.0\n',
#  'Real,7.1,56.0,2.0,6.0,298534.0\n',
#  'The Merciless,6.7,53.0,9.0,21.0,1981.0\n',
#  'A Taxi Driver,7.9,69.0,19.0,32.0,16326.0\n',
#  'Lets Go. JETS! From Small Town Girls to U.S. Champions?!,7.9,82.0,74.0,57.0,205926.0\n',
#  'Evelyn,7.0,55.0,4.0,7.0,6290.0\n',
#  'The Entity,6.7,35.0,1.0,1.0,14925.0\n',
#  'Fantastic Beasts: The Crimes of Grindelwald,6.6,52.0,3.0,22.0,224238.0\n',
#  'Blinded by the Light,6.9,71.0,2.0,6.0,19878.0\n',
#  'Aquaman,6.9,55.0,2.0,39.0,372277.0\n',
#  'Kingsman: The Golden Circle,6.7,44.0,2.0,13.0,274347.0\n',
#  'The Image Book,6.2,76.0,4.0,6.0,2332.0\n',
#  'Sink or Swim,7.0,47.0,5.0,16.0,8807.0\n',
#  'For the Birds,6.8,73.0,2.0,8.0,190.0\n',
#  'Wonder Wheel,6.2,45.0,4.0,4.0,25262.0\n',
#  'Elena,7.6,81.0,11.0,9.0,1704.0\n',
#  'Halloween,6.5,67.0,3.0,25.0,121484.0\n',
#  'American Factory,7.4,86.0,19.0,48.0,17956.0\n',
#  'Lucky,7.3,80.0,16.0,18.0,19518.0\n',
#  'First Man,7.3,84.0,31.0,191.0,169384.0\n',
#  'Instant Family,7.3,57.0,2.0,5.0,89259.0\n',
#  'Escape Room,6.4,48.0,1.0,7.0,88162.0\n',
#  'Roll Red Roll,7.1,83.0,6.0,2.0,1920.0\n',
#  'Fahrenheit 11/9,7.0,69.0,3.0,6.0,18156.0\n',
#  'Screwball,7.1,72.0,2.0,1.0,1284.0\n',
#  'Mollys Game,7.4,71.0,7.0,51.0,144355.0\n',
#  'A Star Is Born,7.6,88.0,95.0,272.0,335490.0\n',
#  'Jungle,6.7,48.0,2.0,5.0,49096.0\n',
#  'The Rider,7.4,92.0,24.0,44.0,14277.0\n',
#  'Sorry to Bother You,6.9,80.0,20.0,56.0,64400.0\n',
#  'Overlord,6.6,60.0,2.0,6.0,86657.0\n',
#  'The Salesman,7.8,85.0,13.0,27.0,51778.0\n',
#  'I Still Know What You Did Last Summer,4.7,21.0,5.0,7.0,68964.0\n',
#  'Bumblebee,6.8,66.0,2.0,13.0,139552.0\n',
#  'A Brighter Summer Day,8.4,90.0,10.0,15.0,7900.0\n',
#  'SAINT JUDY,6.3,51.0,1.0,4.0,1095.0\n',
#  'Tomorrow When the War Began,6.2,54.0,8.0,14.0,30259.0\n',
#  'Anna and the Apocalypse,6.0,63.0,9.0,12.0,10595.0\n',
#  'Darkest Hour,7.4,75.0,53.0,75.0,172970.0\n',
#  'Predator 2,6.3,46.0,1.0,4.0,147027.0\n',
#  'The Monkey King 3,5.5,51.0,1.0,4.0,1204.0\n',
#  'Kamikaze Girls,7.2,56.0,14.0,3.0,6961.0\n',
#  'A Simple Favor,6.8,67.0,3.0,4.0,129797.0\n',
#  'Cities of Last Things,6.2,66.0,6.0,22.0,1254.0\n',
#  'Upgrade,7.5,67.0,3.0,24.0,160328.0\n',
#  'Vox Lux,5.9,67.0,2.0,12.0,16352.0\n',
#  'Pitch Perfect 3,5.8,40.0,5.0,9.0,56523.0\n',
#  'North Country,7.3,68.0,6.0,19.0,40026.0\n',
#  'War for the Planet of the Apes,7.4,82.0,27.0,64.0,228511.0\n',
#  'Dead Calm,6.8,70.0,5.0,6.0,36733.0\n',
#  'Executive Decision,6.4,62.0,2.0,2.0,50899.0\n',
#  'Creed II,7.1,66.0,1.0,12.0,105929.0\n',
#  'Three Identical Strangers,7.6,81.0,11.0,57.0,28081.0\n',
#  'Spider-Man: Into the Spider-Verse,8.4,87.0,79.0,55.0,379220.0\n',
#  'Unbroken,7.2,59.0,16.0,32.0,150384.0\n',
#  'The Front Line,7.4,59.0,16.0,23.0,5984.0\n',
#  'Jules and Jim,7.8,97.0,3.0,4.0,37740.0\n',
#  'Beats,7.1,74.0,5.0,9.0,3203.0\n',
#  'The Edge of Democracy,7.2,81.0,3.0,14.0,13314.0\n',
#  'The Nun,5.3,46.0,2.0,1.0,119020.0\n',
#  'Smallfoot,6.6,60.0,1.0,15.0,34242.0\n',
#  'Its the Law,7.3,69.0,8.0,47.0,460854.0\n',
#  'Roman Holiday,8.0,78.0,11.0,16.0,127445.0\n',
#  'Gifted,7.6,60.0,6.0,7.0,100328.0\n',
#  'Murder Mystery,6.0,38.0,1.0,6.0,103859.0\n',
#  'BlacKkKlansman,7.5,83.0,43.0,208.0,224527.0\n',
#  'Rolling Thunder Revue: A Bob Dylan Story by Martin Scorsese,7.6,86.0,2.0,12.0,5406.0\n',
#  'Crazy Rich Asians,6.9,74.0,13.0,62.0,142865.0\n',
#  'The Black Godfather,7.4,69.0,4.0,5.0,1089.0\n',
#  'I Am Mother,6.7,64.0,4.0,5.0,76522.0\n',
#  'Everybody Knows,6.9,68.0,5.0,33.0,29633.0\n',
#  'Its Okay. Buddy,7.3,69.0,8.0,47.0,460854.0\n',
#  'Dr. Seuss The Grinch,6.3,51.0,1.0,18.0,56100.0\n',
#  'Climax,7.0,67.0,5.0,8.0,53150.0\n',
#  'Shoplifters,7.9,93.0,52.0,97.0,62621.0\n',
#  'The Quake,6.2,70.0,2.0,7.0,9784.0\n',
#  'Marrowbone,6.7,63.0,2.0,2.0,25645.0\n',
#  'Master Z: The Ip Man Legacy,6.5,72.0,2.0,4.0,6946.0\n',
#  'The Post,7.2,83.0,20.0,111.0,136663.0\n',
#  'The Big Sick,7.5,86.0,18.0,92.0,121676.0\n',
#  'Blindspotting,7.4,77.0,7.0,18.0,27383.0\n',
#  'Always Be My Maybe,6.8,64.0,1.0,2.0,46982.0\n',
#  'Playing with Fire,5.1,24.0,2.0,2.0,11019.0\n',
#  'The Meg,5.6,46.0,4.0,6.0,151262.0\n',
#  'Hotel Artemis,6.1,58.0,1.0,1.0,46485.0\n',
#  'Booksmart,7.2,84.0,24.0,53.0,93769.0\n',
#  'Mission: Impossible - Fallout,7.7,86.0,22.0,37.0,292193.0\n',
#  'A Faithful Man,6.2,67.0,4.0,8.0,2958.0\n',
#  'Ben Is Back,6.7,66.0,2.0,10.0,18765.0\n',
#  'Agatha Christies Crooked House,6.3,59.0,2.0,1.0,18188.0\n',
#  'Matangi/Maya/M.I.A.,7.6,70.0,4.0,11.0,1834.0\n',
#  'See You Yesterday,5.2,74.0,2.0,2.0,9344.0\n',
#  'Hagazussa: A Heathens Curse,5.9,72.0,5.0,9.0,4706.0\n',
#  'Support the Girls,6.4,85.0,8.0,19.0,6500.0\n',
#  'RBG,7.6,71.0,13.0,51.0,12700.0\n',
#  'Cold War,7.6,90.0,46.0,116.0,49306.0\n',
#  'Atomic Blonde,6.7,63.0,10.0,18.0,176386.0\n',
#  'The Wife,7.2,77.0,19.0,26.0,35577.0\n',
#  'Breaking In,5.5,42.0,1.0,1.0,14316.0\n',
#  'Shéhérazade,7.1,68.0,7.0,11.0,1593.0\n',
#  'The Midwife,6.7,66.0,1.0,1.0,2545.0\n',
#  'The Day He Arrives,7.0,83.0,3.0,5.0,2204.0\n',
#  'Sgt. Stubby: An American Hero,6.9,58.0,23.0,7.0,1941.0\n',
#  'Okis Movie,6.8,78.0,5.0,3.0,1013.0\n',
#  'Claires Camera,6.5,80.0,2.0,4.0,1917.0\n',
#  'Liz and the Blue Bird,7.2,67.0,1.0,4.0,1120.0\n',
#  'Bathtubs Over Broadway,7.5,78.0,13.0,13.0,852.0\n',
#  'Mid90s,7.4,66.0,4.0,10.0,49788.0\n',
#  'Extremely Wicked. Shockingly Evil and Vile,6.6,52.0,5.0,5.0,79809.0\n',
#  'Prospect,6.3,68.0,6.0,10.0,21597.0\n',
#  'Wildlife,6.8,80.0,6.0,23.0,24420.0\n',
#  'Knock Down The House,7.1,80.0,6.0,11.0,11613.0\n',
#  'The Wandering Earth,6.0,57.0,33.0,37.0,27090.0\n',
#  'Burning,7.5,90.0,58.0,140.0,50002.0\n',
#  'The Hateful Eight: Extended Version,7.8,68.0,42.0,116.0,520333.0\n',
#  'Oceans 8,6.8,61.0,3.0,14.0,189058.0\n',
#  'Time Trap,6.3,46.0,1.0,1.0,28907.0\n',
#  'Sheikh Jackson,7.0,63.0,1.0,4.0,2608.0\n',
#  'Life Itself,6.8,21.0,2.0,4.0,17671.0\n',
#  'Jonathan,5.9,62.0,2.0,1.0,5450.0\n',
#  'The Happytime Murders,5.4,27.0,2.0,10.0,24776.0\n',
#  'Truth or Dare: Extended Directors Cut,5.2,35.0,1.0,4.0,48392.0\n',
#  'The New Romantic,5.7,55.0,1.0,3.0,1930.0\n',
#  'Blaze,6.6,75.0,4.0,12.0,2821.0\n',
#  'A Land Imagined,6.3,59.0,12.0,14.0,1108.0\n',
#  'Tully,7.0,75.0,3.0,23.0,53084.0\n',
#  'Blockers,6.2,69.0,1.0,6.0,71788.0\n',
#  'The Beguiled,6.3,77.0,5.0,29.0,52472.0\n',
#  'Jurassic World: Fallen Kingdom,6.2,51.0,4.0,26.0,267185.0\n',
#  'Paul. Apostle of Christ,6.6,52.0,3.0,3.0,7320.0\n',
#  'Leave No Trace,7.2,88.0,17.0,90.0,51081.0\n',
#  'Snatched,4.5,45.0,2.0,2.0,33289.0\n',
#  'Novitiate,6.7,73.0,5.0,13.0,3878.0\n',
#  'Colette,6.7,74.0,1.0,9.0,19625.0\n',
#  'Golden Exits,5.8,71.0,1.0,6.0,1956.0\n',
#  'Sicario: Day of the Soldado,7.1,61.0,1.0,7.0,126015.0\n',
#  'The Spy Who Dumped Me,6.0,52.0,3.0,4.0,69325.0\n',
#  'Black 47,6.8,65.0,2.0,5.0,10352.0\n',
#  'Detroit,7.3,77.0,5.0,19.0,48441.0\n',
#  'The Burial of Kojo,6.5,93.0,1.0,1.0,595.0\n',
#  'Venom,6.7,35.0,3.0,9.0,362277.0\n',
#  'McQueen,7.8,84.0,1.0,11.0,6390.0\n',
#  'The Miseducation of Cameron Post,6.6,69.0,5.0,15.0,18944.0\n',
#  'The Legend of Cocaine Island,6.3,44.0,2.0,1.0,2819.0\n',
#  'Piercing,5.6,63.0,4.0,8.0,6269.0\n',
#  'The Death of Stalin,7.2,88.0,18.0,38.0,87909.0\n',
#  'The Equalizer 2,6.7,50.0,1.0,4.0,134887.0\n',
#  'All Saints,6.1,63.0,1.0,1.0,1565.0\n',
#  'Serenity,5.4,37.0,3.0,5.0,35929.0\n',
#  'The Dawn Wall,8.1,81.0,6.0,6.0,14912.0\n',
#  'Pick of the Litter,7.5,64.0,8.0,4.0,1279.0\n',
#  'Eighth Grade,7.4,89.0,61.0,89.0,63218.0\n',
#  'The Boy Who Harnessed the Wind,7.6,68.0,3.0,5.0,29245.0\n',
#  'How to Be a Latin Lover,6.0,54.0,2.0,2.0,14223.0\n',
#  'Isnt It Romantic,5.9,60.0,1.0,8.0,63220.0\n',
#  'Searching,7.6,71.0,6.0,10.0,141906.0\n',
#  'Second Act,5.8,46.0,2.0,1.0,22791.0\n',
#  'Revenge,6.4,81.0,3.0,10.0,36518.0\n',
#  'Transformer,7.4,78.0,1.0,1.0,834.0\n',
#  'El ángel,7.0,61.0,20.0,32.0,9134.0\n',
#  'Life of the Party,5.6,46.0,3.0,4.0,33970.0\n',
#  'Studio 54,7.0,70.0,2.0,5.0,2369.0\n',
#  'Hereditary,7.3,87.0,44.0,105.0,241835.0\n',
#  'Magnolia,8.0,77.0,28.0,59.0,290583.0\n',
#  'At Eternitys Gate,6.9,76.0,3.0,16.0,28563.0\n',
#  'Hearts Beat Loud,6.9,65.0,3.0,9.0,9951.0\n',
#  'I Think Were Alone Now,5.7,51.0,2.0,2.0,7752.0\n',
#  'We the Animals,6.9,82.0,12.0,31.0,3808.0\n',
#  'Maudie,7.6,65.0,24.0,17.0,16468.0\n',
#  'Dances with Wolves,8.0,72.0,51.0,38.0,240656.0\n',
#  'Casino Royale,8.0,80.0,27.0,44.0,582997.0\n',
#  'Wont You Be My Neighbor?,8.4,85.0,53.0,32.0,23319.0\n',
#  'Velvet Buzzsaw,5.7,61.0,1.0,2.0,54481.0\n',
#  'Believer,6.5,58.0,7.0,28.0,1914.0\n',
#  'Kingdom,6.6,62.0,3.0,7.0,1708.0\n',
#  'Thank You for Your Service,6.6,68.0,1.0,1.0,12458.0\n',
#  'Hotel Transylvania 3: Summer Vacation,6.3,54.0,2.0,9.0,58293.0\n',
#  'What Keeps You Alive,5.7,66.0,1.0,5.0,6842.0\n',
#  'The Spy Gone North,7.3,69.0,23.0,34.0,3584.0\n',
#  'Ready Player One,7.5,64.0,11.0,56.0,371476.0\n',
#  'Book Club,6.1,53.0,2.0,3.0,25578.0\n',
#  'The Bullet Vanishes,6.6,65.0,4.0,18.0,1945.0\n',
#  'Soni,7.1,68.0,4.0,5.0,2383.0\n',
#  'And Breathe Normally,6.9,77.0,8.0,22.0,2426.0\n',
#  'Pope Francis: A Man of His Word,6.3,63.0,1.0,4.0,2031.0\n',
#  'A Quiet Place,7.5,82.0,34.0,114.0,410706.0\n',
#  'The Witches,6.9,78.0,3.0,8.0,44326.0\n',
#  'Ideal Home,6.4,62.0,2.0,2.0,7884.0\n',
#  'The Book of Henry,6.6,31.0,1.0,3.0,24247.0\n',
#  'Den 12. mann,7.4,70.0,4.0,4.0,20713.0\n',
#  'Overboard (2018),6.0,42.0,3.0,10.0,34546.0\n',
#  'Early Man,6.1,68.0,1.0,10.0,19891.0\n',
#  'Game Night,6.9,66.0,4.0,19.0,207914.0\n',
#  'Di Renjie zhi Sidatianwang,6.4,58.0,1.0,18.0,2311.0\n',
#  'Bird Box,6.6,51.0,5.0,8.0,280672.0\n',
#  'The Indian in the Cupboard,6.0,58.0,1.0,6.0,26340.0\n',
#  'The Mummy,5.4,34.0,6.0,17.0,173510.0\n',
#  'Klovn Forever,6.3,57.0,1.0,1.0,4312.0\n',
#  'ROMA,7.7,96.0,251.0,212.0,140808.0\n',
#  'Goldstone,6.5,78.0,10.0,16.0,4782.0\n',
#  'The Dirty Dozen,7.7,73.0,4.0,9.0,67395.0\n',
#  'Blade Runner: The Final Cut,8.1,84.0,12.0,19.0,695428.0\n',
#  'The Cakemaker,7.2,74.0,18.0,15.0,4075.0\n',
#  'Elvis and Nixon,6.4,59.0,2.0,2.0,13151.0\n',
#  'Journeys End,6.7,73.0,4.0,3.0,7977.0\n',
#  'The Bookshop,6.5,62.0,14.0,33.0,12961.0\n',
#  'Mary Shelley,6.4,49.0,1.0,7.0,13306.0\n',
#  'Summer of 84,6.7,57.0,1.0,5.0,33959.0\n',
#  'Afterimage,7.0,75.0,1.0,12.0,2649.0\n',
#  'Happy as Lazzaro,7.5,87.0,18.0,53.0,15478.0\n',
#  'The World Is Yours,6.4,73.0,1.0,5.0,3712.0\n',
#  'Loveless,7.6,86.0,20.0,47.0,29939.0\n',
#  'Cam,5.9,71.0,5.0,3.0,26964.0\n',
#  'The Ballad of Buster Scruggs,7.3,79.0,7.0,41.0,123563.0\n',
#  'Police Story 2,7.1,68.0,2.0,1.0,17589.0\n',
#  'A Better Tomorrow,7.5,78.0,6.0,14.0,20720.0\n',
#  'A Gentle Creature,6.6,78.0,2.0,13.0,2075.0\n',
#  'BuyBust,5.8,68.0,8.0,30.0,1656.0\n',
#  'The Leisure Seeker,6.7,45.0,3.0,9.0,7497.0\n',
#  'The 15:17 to Paris,5.3,45.0,1.0,3.0,29390.0\n',
#  'The Other Side of the Wind,6.8,78.0,9.0,9.0,6315.0\n',
#  'They’ll Love Me When I’m Dead,7.4,77.0,2.0,2.0,4438.0\n',
#  'Ethel and Ernest,7.8,72.0,3.0,8.0,2844.0\n',
#  'Disobedience,6.6,74.0,4.0,21.0,25444.0\n',
#  'Alien,8.4,89.0,17.0,22.0,789742.0\n',
#  'Heneral Luna,7.5,58.0,17.0,19.0,1889.0\n',
#  'Kai Po Che!,7.7,40.0,11.0,32.0,32623.0\n',
#  'Dovlatov,6.4,68.0,4.0,9.0,1732.0\n',
#  'Shirkers,7.4,88.0,8.0,31.0,4459.0\n',
#  'The Fate of the Furious,6.7,56.0,2.0,12.0,205541.0\n',
#  'Get Out,7.7,85.0,151.0,199.0,495103.0\n',
#  'What Will People Say,7.4,69.0,16.0,13.0,4686.0\n',
#  'The Kindergarten Teacher,6.7,75.0,2.0,12.0,13093.0\n',
#  'Apostle,6.3,62.0,1.0,8.0,43947.0\n',
#  'Murder on the Orient Express,7.3,63.0,9.0,16.0,56138.0\n',
#  'T2: Trainspotting,7.2,67.0,6.0,7.0,114447.0\n',
#  '22 luglio,6.8,69.0,2.0,3.0,28277.0\n',
#  'A Letter to Momo,7.3,65.0,3.0,7.0,6805.0\n',
#  'Private Life,7.2,83.0,1.0,17.0,16246.0\n',
#  'Demolition,7.0,49.0,1.0,2.0,89559.0\n',
#  'Stronger,6.9,76.0,2.0,8.0,40838.0\n',
#  'The Spy,6.6,59.0,18.0,31.0,217014.0\n',
#  'Tazza: The High Rollers,7.2,77.0,18.0,17.0,2042.0\n',
#  'Save the Green Planet!,7.3,70.0,20.0,2.0,7655.0\n',
#  'Spider-Man: Homecoming,7.4,73.0,7.0,10.0,515323.0\n',
#  'Roman Israel. Esq.,6.5,58.0,2.0,10.0,33218.0\n',
#  'Secret Sunshine,7.5,84.0,25.0,15.0,7131.0\n',
#  'Predators,6.4,51.0,2.0,4.0,212134.0\n',
#  'Rough Night,5.2,51.0,1.0,1.0,47330.0\n',
#  'Godzilla: Resurgence,6.8,67.0,13.0,10.0,22748.0\n',
#  'Marshall,7.3,66.0,5.0,19.0,20980.0\n',
#  'Call Me by Your Name,7.9,93.0,97.0,255.0,215122.0\n',
#  'Jumanji: Welcome to the Jungle,6.9,58.0,6.0,18.0,320819.0\n',
#  'Blade Runner 2049,8.0,81.0,97.0,154.0,463964.0\n',
#  'Manchester by the Sea,7.8,96.0,129.0,255.0,248220.0\n',
#  'Flatliners,5.2,27.0,1.0,4.0,42818.0\n',
#  'Baby Driver,7.6,86.0,42.0,65.0,441302.0\n',
#  'Thirteen,6.8,70.0,14.0,49.0,79664.0\n',
#  'Jodhaa Akbar,7.6,69.0,35.0,23.0,29951.0\n',
#  'The German Doctor,6.7,62.0,19.0,22.0,6721.0\n',
#  'Clandestine Childhood,7.0,55.0,22.0,18.0,2402.0\n',
#  'Wonder,8.0,66.0,4.0,29.0,143023.0\n',
#  'Nappily Ever After,6.4,63.0,1.0,5.0,8107.0\n',
#  'Quincy,7.6,60.0,8.0,8.0,3735.0\n',
#  'Paddington 2,7.8,88.0,14.0,44.0,61921.0\n',
#  'The Endless,6.5,80.0,5.0,8.0,34231.0\n',
#  'Split,7.3,62.0,9.0,23.0,428760.0\n',
#  'Die göttliche Ordnung,7.1,67.0,13.0,11.0,2438.0\n',
#  'Jane,7.8,87.0,37.0,37.0,4575.0\n',
#  'A Prayer Before Dawn,6.9,76.0,1.0,6.0,20759.0\n',
#  'Winchester,5.5,28.0,6.0,9.0,30721.0\n',
#  'The Hollars,6.6,53.0,1.0,3.0,11671.0\n',
#  'Florence Foster Jenkins,6.8,71.0,10.0,45.0,51088.0\n',
#  'Mountain,7.2,82.0,3.0,6.0,3784.0\n',
#  'Loving,7.0,79.0,25.0,86.0,32033.0\n',
#  'Justice League,6.3,45.0,2.0,13.0,385856.0\n',
#  'The Lodgers,5.1,52.0,4.0,4.0,8458.0\n',
#  'Peter Rabbit,6.6,51.0,4.0,16.0,35613.0\n',
#  'Resident Evil: The Final Chapter,5.5,49.0,2.0,3.0,84304.0\n',
#  'Big Fish and Begonia,7.1,72.0,3.0,10.0,4807.0\n',
#  'To All the Boys I’ve Loved Before,7.1,64.0,5.0,11.0,88048.0\n',
#  'The Motive,6.5,58.0,18.0,28.0,4826.0\n',
#  'Hostiles,7.2,65.0,4.0,7.0,71990.0\n',
#  'Brothers Friend,7.1,47.0,1.0,2.0,21854.0\n',
#  'Fast Color,6.1,64.0,1.0,7.0,4776.0\n',
#  'Wyatt Earp,6.7,47.0,3.0,7.0,45794.0\n',
#  'The Outsiders,7.1,41.0,1.0,4.0,75887.0\n',
#  'I See You,6.8,65.0,1.0,1.0,30638.0\n',
#  'The Terminal,7.4,55.0,7.0,8.0,408150.0\n',
#  'This Evening,6.4,85.0,16.0,21.0,1809.0\n',
#  'The Master,7.2,86.0,75.0,187.0,155991.0\n',
#  'Demons Path,6.1,80.0,2.0,7.0,5238.0\n',
#  'Love for Sale,7.2,62.0,28.0,26.0,1605.0\n',
#  'Paprika,7.7,81.0,6.0,5.0,71845.0\n',
#  'Single White Female,6.4,63.0,1.0,1.0,32388.0\n',
#  'Love In The Buff,6.8,65.0,2.0,6.0,1671.0\n',
#  'Election 2,7.4,83.0,1.0,14.0,5731.0\n',
#  'The Bleeding Edge,7.7,74.0,2.0,2.0,2190.0\n',
#  'The Nutty Professor II: The Klumps,4.4,38.0,2.0,15.0,48311.0\n',
#  'Downsizing,5.7,63.0,1.0,16.0,99276.0\n',
#  'The Iron Ladies,6.4,50.0,10.0,4.0,1331.0\n',
#  'One Piece Film: Gold,7.2,43.0,1.0,3.0,4058.0\n',
#  'Geostorm,5.3,21.0,1.0,1.0,95157.0\n',
#  'I Feel Pretty,5.5,48.0,1.0,7.0,49029.0\n',
#  'The Devil Wears Prada,6.9,62.0,20.0,52.0,372576.0\n',
#  'Independence Day,7.0,59.0,35.0,35.0,528920.0\n',
#  'Aliens,8.3,84.0,20.0,23.0,654147.0\n',
#  'Alien Resurrection,6.2,63.0,7.0,21.0,229629.0\n',
#  'Alien vs. Predator,5.6,29.0,2.0,4.0,185073.0\n',
#  'Same Kind of Different as Me,6.6,47.0,1.0,1.0,6463.0\n',
#  'Daddys Home 2,6.0,30.0,1.0,11.0,62895.0\n',
#  'White Fang,7.0,61.0,1.0,4.0,3173.0\n',
#  'I. Tonya,7.5,77.0,46.0,120.0,183143.0\n',
#  'The Frighteners,7.1,52.0,3.0,16.0,82373.0\n',
#  'Certain Women,6.3,82.0,12.0,47.0,12142.0\n',
#  'Dogtown and Z-Boys,7.7,76.0,7.0,6.0,12308.0\n',
#  'Duck Butter,5.3,58.0,2.0,1.0,3223.0\n',
#  'True Lies,7.2,63.0,8.0,23.0,238573.0\n',
#  'It Takes Two,5.9,45.0,1.0,3.0,20870.0\n',
#  'Ice Age,7.5,60.0,5.0,30.0,443268.0\n',
#  'Ice Age: Dawn of the Dinosaurs,6.9,50.0,3.0,13.0,224642.0\n',
#  'Suburbicon,5.7,42.0,4.0,8.0,40618.0\n',
#  'Loving Pablo,6.3,42.0,1.0,5.0,18228.0\n',
#  'Calibre,6.8,76.0,2.0,7.0,22865.0\n',
#  'Lu Over the Wall,6.8,62.0,1.0,2.0,1816.0\n',
#  'It,7.3,69.0,8.0,47.0,460854.0\n',
#  'Passengers,7.0,41.0,1.0,12.0,351103.0\n',
#  'Sundays Illness,6.9,92.0,7.0,12.0,3033.0\n',
#  'Sweet Country,6.9,87.0,22.0,29.0,7450.0\n',
#  'Dunkirk,7.8,94.0,64.0,228.0,556842.0\n',
#  'An Officer and a Gentleman,7.0,75.0,9.0,13.0,49685.0\n',
#  'Alis Wedding,6.9,64.0,8.0,23.0,4399.0\n',
#  'Billy Lynns Long Halftime Walk,6.2,53.0,2.0,7.0,21177.0\n',
#  'Lady Bird,7.4,94.0,116.0,224.0,243256.0\n',
#  'Thelma,7.0,74.0,15.0,46.0,26944.0\n',
#  'The Disaster Artist,7.4,76.0,31.0,79.0,138382.0\n',
#  '5 Fingers for Marseilles,6.2,73.0,8.0,12.0,780.0\n',
#  'Police Story,7.6,78.0,2.0,5.0,29914.0\n',
#  'Mother!,6.6,75.0,9.0,41.0,192493.0\n',
#  'New Jack City,6.7,61.0,1.0,5.0,31771.0\n',
#  'The Hero,6.5,61.0,2.0,6.0,8137.0\n',
#  'Beatriz at Dinner,6.0,68.0,2.0,8.0,9081.0\n',
#  'The Glass Castle,7.2,56.0,1.0,2.0,29992.0\n',
#  'Dean,6.3,58.0,2.0,1.0,2256.0\n',
#  'The Night Is Short. Walk On Girl,7.6,65.0,2.0,5.0,3908.0\n',
#  'Annabelle: Creation,6.5,62.0,1.0,7.0,113029.0\n',
#  'Faces Places,7.9,94.0,36.0,40.0,10898.0\n',
#  'Brads Status,6.5,71.0,1.0,2.0,16078.0\n',
#  'Pilgrimage,5.8,60.0,1.0,3.0,4698.0\n',
#  'Falling Down,7.6,56.0,1.0,2.0,172474.0\n',
#  'Swept Away,3.6,18.0,8.0,8.0,15788.0\n',
#  'Ouija: Origin of Evil,6.1,65.0,2.0,7.0,54308.0\n',
#  'A Bride for Rip Van Winkle,7.2,56.0,2.0,6.0,1388.0\n',
#  'Mom and Dad,5.5,59.0,1.0,2.0,20749.0\n',
#  'Captain Fantastic,7.9,72.0,15.0,50.0,189498.0\n',
#  'Monty Python and the Holy Grail,8.2,91.0,3.0,3.0,502049.0\n',
#  'Borg vs. McEnroe,6.9,63.0,7.0,13.0,28122.0\n',
#  'The Florida Project,7.6,92.0,66.0,129.0,96017.0\n',
#  'The Killing of a Sacred Deer,7.0,73.0,5.0,53.0,125746.0\n',
#  'An Inconvenient Sequel: Truth to Power,6.4,68.0,6.0,15.0,7652.0\n',
#  'Silverado,7.2,64.0,1.0,4.0,38489.0\n',
#  'Undercover Kitty,6.8,50.0,8.0,2.0,4773.0\n',
#  'Inferno,6.2,42.0,4.0,1.0,160487.0\n',
#  'Better Watch Out,6.5,67.0,8.0,2.0,32265.0\n',
#  'Love and Death,7.7,89.0,3.0,2.0,36031.0\n',
#  'Kicks,6.4,69.0,4.0,3.0,4138.0\n',
#  'Saturday Church,6.4,72.0,14.0,5.0,762.0\n',
#  'Hush,5.5,18.0,1.0,2.0,10553.0\n',
#  'Gods Own Country,7.7,85.0,31.0,39.0,25480.0\n',
#  'First Match,6.4,68.0,2.0,1.0,1980.0\n',
#  'The Bodyguard,6.3,39.0,10.0,21.0,120087.0\n',
#  'Roxanne Roxanne,6.2,74.0,1.0,4.0,2798.0\n',
#  'Wonder Woman,7.4,76.0,24.0,71.0,570776.0\n',
#  'The Beatles: Eight Days a Week,7.8,72.0,5.0,14.0,11434.0\n',
#  'A Man in the Dark,7.1,71.0,7.0,21.0,223676.0\n',
#  'In This Corner of the World,7.8,73.0,10.0,10.0,8977.0\n',
#  'Annihilation,6.8,79.0,16.0,56.0,282373.0\n',
#  'Bitch,5.1,55.0,1.0,1.0,1735.0\n',
#  '68 Kill,6.0,56.0,3.0,1.0,4945.0\n',
#  'Nocturnal Animals,7.5,67.0,20.0,148.0,239999.0\n',
#  'The Shack,6.3,32.0,3.0,2.0,30671.0\n',
#  'A Perfect Murder,6.5,50.0,2.0,3.0,79406.0\n',
#  'Happy Family,7.4,86.0,13.0,10.0,3161.0\n',
#  'Columbus,7.2,89.0,9.0,29.0,14556.0\n',
#  'A Silent Voice,8.1,78.0,4.0,8.0,48554.0\n',
#  'Loving Vincent,7.8,62.0,22.0,51.0,50988.0\n',
#  'Wind River,7.7,73.0,14.0,26.0,207223.0\n',
#  'Guru,7.7,70.0,17.0,33.0,22044.0\n',
#  'LA 92,8.2,66.0,3.0,8.0,5562.0\n',
#  'Beach Rats,6.4,78.0,12.0,16.0,12652.0\n',
#  'The Bridges of Madison County,7.6,69.0,7.0,18.0,73431.0\n',
#  'The Zookeepers Wife,7.0,57.0,2.0,3.0,38813.0\n',
#  'Lincoln,7.3,86.0,109.0,251.0,245650.0\n',
#  'The Breadwinner,7.7,78.0,20.0,54.0,20926.0\n',
#  'John Wick: Chapter Two,7.5,75.0,4.0,10.0,367362.0\n',
#  'The Villainess,6.7,64.0,6.0,13.0,12346.0\n',
#  'Trophy,7.3,80.0,1.0,6.0,617.0\n',
#  'Breathe,7.2,51.0,1.0,4.0,19275.0\n',
#  'The Ritual,6.3,57.0,4.0,4.0,78411.0\n',
#  'The Emoji Movie,3.3,12.0,7.0,3.0,56232.0\n',
#  'Ingrid Goes West,6.6,71.0,2.0,9.0,36264.0\n',
#  'On Body and Soul,7.6,77.0,17.0,19.0,24150.0\n',
#  'Lost City of Z,6.6,78.0,6.0,31.0,80547.0\n',
#  'Any Given Sunday,6.9,52.0,3.0,9.0,112334.0\n',
#  'Baywatch,5.5,37.0,5.0,11.0,162201.0\n',
#  'Transformers: The Last Knight,5.2,27.0,4.0,19.0,136008.0\n',
#  'The Avengers,3.8,12.0,4.0,17.0,41038.0\n',
#  'Born to Be Blue,6.9,64.0,3.0,7.0,8053.0\n',
#  'Found,5.9,41.0,25.0,8.0,3814.0\n',
#  'The Girl on the Train,6.5,48.0,4.0,12.0,169614.0\n',
#  'Ghostbusters,6.4,60.0,5.0,24.0,204928.0\n',
#  'Captain Underpants: The First Epic Movie,6.2,69.0,3.0,15.0,25081.0\n',
#  'Good Time,7.4,80.0,6.0,49.0,91250.0\n',
#  'A Bad Moms Christmas,5.6,42.0,1.0,1.0,45151.0\n',
#  'A Ghost Story,6.9,84.0,12.0,20.0,61150.0\n',
#  'Suffragette,6.9,66.0,17.0,16.0,38489.0\n',
#  'The Shallows,6.3,59.0,1.0,15.0,120760.0\n',
#  'Die Hard 4.0,7.1,69.0,3.0,16.0,390192.0\n',
#  'Tatsumi,7.1,78.0,3.0,6.0,702.0\n',
#  'Lost Highway,7.6,52.0,4.0,6.0,131838.0\n',
#  'The Brand New Testament,7.1,70.0,14.0,25.0,30082.0\n',
#  'Creepy,6.3,76.0,3.0,1.0,4391.0\n',
#  'Kong: Skull Island,6.6,62.0,1.0,21.0,271946.0\n',
#  'The Lego Batman Movie,7.3,75.0,13.0,67.0,131509.0\n',
#  'Logan Lucky,7.0,78.0,2.0,11.0,131724.0\n',
#  'Clash,7.5,78.0,11.0,8.0,5038.0\n',
#  'CHIPS,6.0,28.0,2.0,1.0,42597.0\n',
#  'Mr. Roosevelt,6.2,73.0,5.0,4.0,2807.0\n',
#  'Creep 2,6.5,75.0,2.0,1.0,19975.0\n',
#  'Bright,6.3,29.0,1.0,7.0,169376.0\n',
#  'Live Flesh,7.4,69.0,11.0,14.0,28561.0\n',
#  'The Flower of My Secret,7.0,75.0,5.0,13.0,10443.0\n',
#  'Bad Education,7.4,81.0,16.0,42.0,55919.0\n',
#  'Menashe,6.5,81.0,9.0,18.0,1988.0\n',
#  'Love Me If You Dare,7.6,45.0,5.0,2.0,67508.0\n',
#  'Fist Fight,5.6,37.0,1.0,1.0,39746.0\n',
#  'Peepli Live,7.4,69.0,4.0,13.0,11826.0\n',
#  'Lagaan,8.1,84.0,54.0,20.0,105212.0\n',
#  'Dhobi Ghat (Mumbai Diaries),7.0,55.0,1.0,3.0,12488.0\n',
#  'Delhi Belly,7.6,66.0,6.0,9.0,27562.0\n',
#  'By the Sea,5.3,44.0,1.0,2.0,18777.0\n',
#  'Your Name,8.4,79.0,16.0,25.0,197791.0\n',
#  'My Happy Family,7.4,86.0,13.0,10.0,3161.0\n',
#  'American Graffiti,7.4,97.0,9.0,13.0,82037.0\n',
#  'Cool Hand Luke,8.1,92.0,4.0,10.0,162571.0\n',
#  'High Heels,7.1,51.0,11.0,9.0,14038.0\n',
#  'Wakefield,6.3,62.0,1.0,1.0,15464.0\n',
#  'The Boss Baby,6.3,50.0,4.0,21.0,109139.0\n',
#  'Collateral Beauty,6.8,23.0,1.0,6.0,91920.0\n',
#  'Mudbound,7.4,85.0,35.0,117.0,43081.0\n',
#  'Jim and Andy: The Great Beyond - Featuring a Very Special. Contractually Obligated Mention of Tony Clifton,7.7,77.0,3.0,7.0,23180.0\n',
#  'Billy Elliot,7.7,74.0,56.0,73.0,127066.0\n',
#  'Midnight Run,7.5,78.0,2.0,4.0,76038.0\n',
#  'Hickok,4.7,49.0,2.0,1.0,2719.0\n',
#  'Free Fire,6.4,63.0,3.0,8.0,42332.0\n',
#  'Megan Leavey,7.1,66.0,1.0,1.0,21739.0\n',
#  'Their Finest,6.8,76.0,1.0,7.0,18062.0\n',
#  'Women on the Verge of a Nervous Breakdown,7.6,85.0,22.0,24.0,36189.0\n',
#  'La La Land,8.0,94.0,242.0,281.0,508025.0\n',
#  'Let It Fall: Los Angeles 1982-1992,7.8,92.0,6.0,3.0,663.0\n',
#  'The Dinner,4.5,57.0,1.0,2.0,7873.0\n',
#  '6 Days,6.2,36.0,1.0,2.0,18656.0\n',
#  'Frank and Lola,5.9,56.0,1.0,2.0,5534.0\n',
#  'A Cure for Wellness,6.4,47.0,4.0,5.0,86916.0\n',
#  'A United Kingdom,6.9,65.0,2.0,4.0,14499.0\n',
#  'Mean Dreams,6.3,64.0,1.0,5.0,4198.0\n',
#  'Field of Dreams,7.5,57.0,7.0,13.0,108380.0\n',
#  'The Crush,5.9,34.0,2.0,3.0,16604.0\n',
#  'Angel Eyes,5.6,39.0,3.0,5.0,22562.0\n',
#  'Adult Life Skills,6.3,49.0,6.0,10.0,3294.0\n',
#  'Strange Weather,5.9,57.0,1.0,1.0,1187.0\n',
#  'Black,6.2,43.0,2.0,2.0,12610.0\n',
#  'Urban Legend,5.6,35.0,1.0,2.0,60496.0\n',
#  'It Comes at Night,6.2,78.0,1.0,11.0,84529.0\n',
#  'Black Butterfly,6.2,43.0,2.0,2.0,12610.0\n',
#  '1922,6.3,70.0,1.0,4.0,53636.0\n',
#  'Smurfs: The Lost Village,6.0,40.0,1.0,6.0,18627.0\n',
#  'Colossal,6.2,70.0,3.0,8.0,59188.0\n',
#  'The Abyss,7.5,62.0,9.0,15.0,162973.0\n',
#  'The Meyerowitz Stories (New and Selected),6.9,79.0,4.0,7.0,42985.0\n',
#  'Norman: The Moderate Rise and Tragic Fall of a New York Fixer,6.1,75.0,1.0,1.0,5695.0\n',
#  'Kidnap,5.9,44.0,2.0,4.0,34029.0\n',
#  'The Death and Life of Marsha P. Johnson,7.3,76.0,3.0,5.0,2311.0\n',
#  'Shinjuku Incident,7.0,63.0,1.0,6.0,11692.0\n',
#  'Patriots Day,7.4,69.0,2.0,3.0,92601.0\n',
#  'Dangerous Liaisons,7.6,74.0,21.0,21.0,64704.0\n',
#  'Asura: The City of Madness,6.6,64.0,6.0,16.0,2307.0\n',
#  'The Handmaiden,8.1,84.0,68.0,104.0,114432.0\n',
#  'Geralds Game,6.6,77.0,4.0,4.0,90638.0\n',
#  'Bobby Sands: 66 Days,7.2,71.0,1.0,3.0,605.0\n',
#  'Gaga: Five Foot Two,7.0,63.0,4.0,1.0,11663.0\n',
#  'The Bad Batch,5.3,62.0,1.0,3.0,26804.0\n',
#  'Fantastic Beasts and Where To Find Them,7.3,66.0,15.0,53.0,411828.0\n',
#  'The Dressmaker,7.1,47.0,15.0,39.0,54330.0\n',
#  'First They Killed My Father,7.2,72.0,9.0,28.0,15792.0\n',
#  'Strong Island,6.4,86.0,13.0,12.0,3545.0\n',
#  'Voice from the Stone,5.2,42.0,1.0,2.0,10590.0\n',
#  'The Visit,6.2,55.0,1.0,14.0,114273.0\n',
#  ...]

# %%
dati = {"Title":[], "IMDb_score":[], "Metacritic_score":[], "Awards_Received":[], "Awards_Nominated":[], "IMDb_votes":[] }

# %%
for riga in righe[1:]:
    lista_Campi = riga[:-1].split(",")
    dati["Title"].append(lista_Campi[0])
    dati["IMDb_score"].append(float(lista_Campi[1]))
    dati["Metacritic_score"].append(float(lista_Campi[2]))
    dati["Awards_Received"].append(float(lista_Campi[3]))
    dati["Awards_Nominated"].append(float(lista_Campi[4]))
    dati["IMDb_votes"].append(float(lista_Campi[5]))
    
for nome, d in dati.items():
    dati[nome] = np.array(d)
dati
# Out:
# {'Title': array(['Lets Fight Ghost', 'Joker', 'I', ...,
#         'The Twilight Saga: Breaking Dawn: Part 1', 'One for the Money',
#         '13'], dtype='<U106'),
#  'IMDb_score': array([7.9, 8.4, 6.5, ..., 4.9, 5.3, 6.1]),
#  'Metacritic_score': array([82., 59., 51., ..., 45., 22., 29.]),
#  'Awards_Received': array([ 74., 112.,  26., ...,  11.,   1.,   1.]),
#  'Awards_Nominated': array([ 57., 228.,  69., ...,  22.,   1.,   1.]),
#  'IMDb_votes': array([205926., 951938., 733336., ..., 224372.,  40841.,  40425.])}

# %%
colori = np.random.uniform(0.,1.,(10,3))

# %%
fig, axs = plt.subplots(nrows=1 , ncols=2 , figsize = (7,4))
axs[0].scatter(dati["IMDb_score"], dati["Awards_Received"], marker = "v")
axs[0].set_xlabel("IMDb_score", fontsize = 10)
axs[0].set_ylabel("Awards_Received", fontsize = 10)
axs[0].set_title("Confronto 1", fontsize = 15)

axs[1].scatter(dati["IMDb_score"], dati["IMDb_votes"], marker = "2")
axs[1].set_xlabel("IMDb_score", fontsize = 10)
axs[1].set_ylabel("Awards_votes", fontsize = 10)
axs[1].set_title("Confronto 2", fontsize = 15)

plt.show()

# %%
fig, ax = plt.subplots(figsize = (7,7))
ax.scatter(dati["IMDb_score"], dati["Awards_Received"], marker = "v", s = dati["IMDb_votes"]/1000)
ax.set_xlabel("IMDb_score", fontsize = 10)
ax.set_ylabel("Awards_Received", fontsize = 10)
ax.set_title("Confronto", fontsize = 15)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
